# %%
# Installing required packages
# !pip install pyspark
# !pip install findspark
# Out:
# Requirement already satisfied: pyspark in c:\users\emerjuni\anaconda3\lib\site-packages (3.2.1)
# Requirement already satisfied: py4j==0.10.9.3 in c:\users\emerjuni\anaconda3\lib\site-packages (from pyspark) (0.10.9.3)
# Requirement already satisfied: findspark in c:\users\emerjuni\anaconda3\lib\site-packages (2.0.1)

# %%
import findspark
findspark.init()

# %%
# PySpark is the Spark API for Python. In this lab, we use PySpark to initialize the spark context. 
from pyspark.sql.types import StructType,StructField, StringType, IntegerType, DoubleType, TimestampType
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

# %%
# Creating a spark context class
sc = SparkContext()

# Creating a spark session
spark = SparkSession \
    .builder \
    .appName("Prática da semana 2 - Aceleração Pyspark") \
    .config("spark.some.config.option", "some-value") \
    .config("spark.memory.offHeap.enabled","true") \
    .config("spark.memory.offHeap.size","10g")\
    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LBR-PE08091L.corp.capgemini.com:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # Airports

# %%
schema_air = StructType()\
    .add('faa', StringType(), True)\
    .add('name', StringType(), True)\
    .add('lat', DoubleType(), True)\
    .add('lon', DoubleType(), True)\
    .add('alt', DoubleType(), True)\
    .add('tz', IntegerType(), True)\
    .add('dst', StringType(), True)

airports = spark.read.format('csv')\
    .option('header', True)\
    .schema(schema_air)\
    .load('C:/Practice_Pyspark/airports.csv')

airports.printSchema()
# Out:
# root
#  |-- faa: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- lat: double (nullable = true)
#  |-- lon: double (nullable = true)
#  |-- alt: double (nullable = true)
#  |-- tz: integer (nullable = true)
#  |-- dst: string (nullable = true)

# %%
airports.toPandas()
# Out:
#       faa                           name        lat         lon     alt  tz  \
# 0     04G              Lansdowne Airport  41.130472  -80.619583  1044.0  -5
# 1     06A  Moton Field Municipal Airport  32.460572  -85.680028   264.0  -5
# 2     06C            Schaumburg Regional  41.989341  -88.101243   801.0  -6
# 3     06N                Randall Airport  41.431912  -74.391561   523.0  -5
# 4     09J          Jekyll Island Airport  31.074472  -81.427778    11.0  -4
# ...   ...                            ...        ...         ...     ...  ..
# 1392  ZUN                     Black Rock  35.083228 -108.791778  6454.0  -7
# 1393  ZVE         New Haven Rail Station  41.298669  -72.925992     7.0  -5
# 1394  ZWI      Wilmington Amtrak Station  39.736667  -75.551667     0.0  -5
# 1395  ZWU       Washington Union Station  38.897460  -77.006430    76.0  -5
# 1396  ZYP                   Penn Station  40.750500  -73.993500    35.0  -5
#
#      dst         region type  military administration
# 0      A  MAINLAND-EAST   AP     False            NaN
# 1      A  MAINLAND-EAST   AP     False            NaN
# 2      A  MAINLAND-EAST  NaN     False            NaN
# 3      A  MAINLAND-EAST   AP     False            NaN
# 4      A  MAINLAND-EAST   AP     False            NaN
# ...   ..            ...  ...       ...            ...
# 1392   A  MAINLAND-WEST  NaN     False            NaN
# 1393   A  MAINLAND-EAST   AS     False            NaN
# 1394   A  MAINLAND-EAST   AS     False            NaN
# 1395   A  MAINLAND-EAST   AS     False            NaN
# 1396   A  MAINLAND-EAST   AS     False            NaN
#
# [1397 rows x 11 columns]

# %% [markdown]
# ### Pergunta 1

# %%
airports = airports.withColumn('alt',
                              F.when(F.col('alt') < 0, 0)    
                              .otherwise(F.col('alt')))

# %%
airports.select('alt').filter(F.col('alt') != 0).show()
# Out:
# +------+
# |   alt|
# +------+
# |1044.0|
# | 264.0|
# | 801.0|
# | 523.0|
# |  11.0|
# |1593.0|
# | 730.0|
# | 492.0|
# |1000.0|
# | 108.0|
# | 409.0|
# | 875.0|
# |1003.0|
# | 951.0|
# |1789.0|
# | 122.0|
# | 152.0|
# | 670.0|
# |1134.0|
# | 885.0|
# +------+
# only showing top 20 rows

# %% [markdown]
# ### Pergunta 2

# %%
airports = airports.withColumn('dst',
                              F.when(
                                  F.col('tz').between(-7, -5), 'A')
                              .otherwise(F.col('dst')))

# %%
airports.filter((F.col('dst') == 'U')).show(5)
# Out:
# +---+--------------------+----------+-------------+------+---+---+
# |faa|                name|       lat|          lon|   alt| tz|dst|
# +---+--------------------+----------+-------------+------+---+---+
# |19A|Jackson County Ai...|34.1758638|  -83.5615972| 951.0| -4|  U|
# |BLD|Boulder City Muni...|   35.5651|     -114.514|2201.0| -8|  U|
# |GCW|Grand Canyon West...|   35.5925|    -113.4859|4825.0| -8|  U|
# |MXY|    McCarthy Airport|61.4370608|-142.90307372|1531.0| -8|  U|
# |NGZ|         NAS Alameda|   37.7861|    -122.3186|  10.0| -9|  U|
# +---+--------------------+----------+-------------+------+---+---+
# only showing top 5 rows

# %% [markdown]
# ### Pergunta 3

# %%
airports = airports.withColumn('dst',
                              F.when(F.col('dst') == 'U', 'A')
                              .otherwise(F.col('dst')))

# %%
airports.select('dst').filter(F.col('dst') == 'U').show()
# Out:
# +---+
# |dst|
# +---+
# +---+

# %% [markdown]
# ### Pergunta 4

# %%
airports = airports.withColumn('region',
                              F.when(F.col('lon') < -124, 'ALASKA')
                              .when(
                                  (F.col('lon') > -50) | (F.col('lat') < 24), 'OFFSHORE')
                              .when(F.col('lon').between(-124, -95), 'MAINLAND-WEST')
                              .when(
                                  (F.col('lon') > -95) & 
                                  (F.col('lon') <= -50), 'MAINLAND-EAST')
                              .otherwise(float('nan')))

# %%
airports.show(truncate = False)
# Out:
# +---+------------------------------------+----------------+-----------------+------+---+---+-------------+
# |faa|name                                |lat             |lon              |alt   |tz |dst|region       |
# +---+------------------------------------+----------------+-----------------+------+---+---+-------------+
# |04G|Lansdowne Airport                   |41.1304722      |-80.6195833      |1044.0|-5 |A  |MAINLAND-EAST|
# |06A|Moton Field Municipal Airport       |32.4605722      |-85.6800278      |264.0 |-5 |A  |MAINLAND-EAST|
# |06C|Schaumburg Regional                 |41.9893408      |-88.1012428      |801.0 |-6 |A  |MAINLAND-EAST|
# |06N|Randall Airport                     |41.431912       |-74.3915611      |523.0 |-5 |A  |MAINLAND-EAST|
# |09J|Jekyll Island Airport               |31.0744722      |-81.4277778      |11.0  |-4 |A  |MAINLAND-EAST|
# |0A9|Elizabethton Municipal Airport      |36.3712222      |-82.1734167      |1593.0|-4 |A  |MAINLAND-EAST|
# |0G6|Williams County Airport             |41.4673056      |-84.5067778      |730.0 |-5 |A  |MAINLAND-EAST|
# |0G7|Finger Lakes Regional Airport       |42.8835647      |-76.7812318      |492.0 |-5 |A  |MAINLAND-EAST|
# |0P2|Shoestring Aviation Airfield        |39.7948244      |-76.6471914      |1000.0|-5 |A  |MAINLAND-EAST|
# |0S9|Jefferson County Intl               |48.0538086      |-122.8106436     |108.0 |-8 |A  |MAINLAND-WEST|
# |0W3|Harford County Airport              |39.5668378      |-76.2024028      |409.0 |-5 |A  |MAINLAND-EAST|
# |10C|Galt Field Airport                  |42.4028889      |-88.3751111      |875.0 |-6 |A  |MAINLAND-EAST|
# |17G|Port Bucyrus-Crawford County Airport|40.7815556      |-82.9748056      |1003.0|-5 |A  |MAINLAND-EAST|
# |19A|Jackson County Airport              |34.1758638      |-83.5615972      |951.0 |-4 |A  |MAINLAND-EAST|
# |1A3|Martin Campbell Field Airport       |35.0158056      |-84.3468333      |1789.0|-4 |A  |MAINLAND-EAST|
# |1B9|Mansfield Municipal                 |42.0001331      |-71.1967714      |122.0 |-5 |A  |MAINLAND-EAST|
# |1C9|Frazier Lake Airpark                |54.0133333333333|-124.768333333333|152.0 |-8 |A  |ALASKA       |
# |1CS|Clow International Airport          |41.6959744      |-88.1292306      |670.0 |-6 |A  |MAINLAND-EAST|
# |1G3|Kent State Airport                  |41.1513889      |-81.4151111      |1134.0|-4 |A  |MAINLAND-EAST|
# |1OH|Fortman Airport                     |40.5553253      |-84.3866186      |885.0 |-5 |A  |MAINLAND-EAST|
# +---+------------------------------------+----------------+-----------------+------+---+---+-------------+
# only showing top 20 rows

# %% [markdown]
# ### Pergunta 5

# %%
AP_CONDITION = ["Airport", "Tradeport", "Heliport", "Airpor", "Arpt"]

AP_REGEX = r'|'.join(map(lambda x : f".*({x}).*", AP_CONDITION))

# %%
AP_REGEX
# Out:
# '.*(Airport).*|.*(Tradeport).*|.*(Heliport).*|.*(Airpor).*|.*(Arpt).*'

# %%
airports = airports.withColumn('type', 
                              F.when(F.col('name').rlike(AP_REGEX), 'AP')
                              .when(F.col('name').contains('Aerodrome'), 'AD')
                              .when(F.col('name').rlike('.*Airpark.*|.*Aero Park.*'), 'AK')
                              .when(F.col('name').rlike('.*Station.*|.*Air Station.*'), 'AS')
                              .when(F.col('name').rlike('.*Field.*|.*Fld.*'), 'FL')
                              .otherwise(float('nan')))

# %%
airports.show(truncate = False)
# Out:
# +---+------------------------------------+----------------+-----------------+------+---+---+-------------+----+
# |faa|name                                |lat             |lon              |alt   |tz |dst|region       |type|
# +---+------------------------------------+----------------+-----------------+------+---+---+-------------+----+
# |04G|Lansdowne Airport                   |41.1304722      |-80.6195833      |1044.0|-5 |A  |MAINLAND-EAST|AP  |
# |06A|Moton Field Municipal Airport       |32.4605722      |-85.6800278      |264.0 |-5 |A  |MAINLAND-EAST|AP  |
# |06C|Schaumburg Regional                 |41.9893408      |-88.1012428      |801.0 |-6 |A  |MAINLAND-EAST|NaN |
# |06N|Randall Airport                     |41.431912       |-74.3915611      |523.0 |-5 |A  |MAINLAND-EAST|AP  |
# |09J|Jekyll Island Airport               |31.0744722      |-81.4277778      |11.0  |-4 |A  |MAINLAND-EAST|AP  |
# |0A9|Elizabethton Municipal Airport      |36.3712222      |-82.1734167      |1593.0|-4 |A  |MAINLAND-EAST|AP  |
# |0G6|Williams County Airport             |41.4673056      |-84.5067778      |730.0 |-5 |A  |MAINLAND-EAST|AP  |
# |0G7|Finger Lakes Regional Airport       |42.8835647      |-76.7812318      |492.0 |-5 |A  |MAINLAND-EAST|AP  |
# |0P2|Shoestring Aviation Airfield        |39.7948244      |-76.6471914      |1000.0|-5 |A  |MAINLAND-EAST|NaN |
# |0S9|Jefferson County Intl               |48.0538086      |-122.8106436     |108.0 |-8 |A  |MAINLAND-WEST|NaN |
# |0W3|Harford County Airport              |39.5668378      |-76.2024028      |409.0 |-5 |A  |MAINLAND-EAST|AP  |
# |10C|Galt Field Airport                  |42.4028889      |-88.3751111      |875.0 |-6 |A  |MAINLAND-EAST|AP  |
# |17G|Port Bucyrus-Crawford County Airport|40.7815556      |-82.9748056      |1003.0|-5 |A  |MAINLAND-EAST|AP  |
# |19A|Jackson County Airport              |34.1758638      |-83.5615972      |951.0 |-4 |A  |MAINLAND-EAST|AP  |
# |1A3|Martin Campbell Field Airport       |35.0158056      |-84.3468333      |1789.0|-4 |A  |MAINLAND-EAST|AP  |
# |1B9|Mansfield Municipal                 |42.0001331      |-71.1967714      |122.0 |-5 |A  |MAINLAND-EAST|NaN |
# |1C9|Frazier Lake Airpark                |54.0133333333333|-124.768333333333|152.0 |-8 |A  |ALASKA       |AK  |
# |1CS|Clow International Airport          |41.6959744      |-88.1292306      |670.0 |-6 |A  |MAINLAND-EAST|AP  |
# |1G3|Kent State Airport                  |41.1513889      |-81.4151111      |1134.0|-4 |A  |MAINLAND-EAST|AP  |
# |1OH|Fortman Airport                     |40.5553253      |-84.3866186      |885.0 |-5 |A  |MAINLAND-EAST|AP  |
# +---+------------------------------------+----------------+-----------------+------+---+---+-------------+----+
# only showing top 20 rows

# %% [markdown]
# ### Pergunta 6

# %%
MILITARY = ["Base", "Aaf", "AFs", "Ahp", "Afb", "LRRS", "Lrrs", "Arb", "Naf", "NAS", "Nas", "Jrb", "Ns", "As", "Cgas", "Angb"]

MILITARY_REGEX = r'|'.join(map(lambda x : f"(^{x} .*|.* {x} .*|.* {x}$)", MILITARY))

# %%
MILITARY_REGEX
# Out:
# '(^Base .*|.* Base .*|.* Base$)|(^Aaf .*|.* Aaf .*|.* Aaf$)|(^AFs .*|.* AFs .*|.* AFs$)|(^Ahp .*|.* Ahp .*|.* Ahp$)|(^Afb .*|.* Afb .*|.* Afb$)|(^LRRS .*|.* LRRS .*|.* LRRS$)|(^Lrrs .*|.* Lrrs .*|.* Lrrs$)|(^Arb .*|.* Arb .*|.* Arb$)|(^Naf .*|.* Naf .*|.* Naf$)|(^NAS .*|.* NAS .*|.* NAS$)|(^Nas .*|.* Nas .*|.* Nas$)|(^Jrb .*|.* Jrb .*|.* Jrb$)|(^Ns .*|.* Ns .*|.* Ns$)|(^As .*|.* As .*|.* As$)|(^Cgas .*|.* Cgas .*|.* Cgas$)|(^Angb .*|.* Angb .*|.* Angb$)'

# %%
airports = airports.withColumn('military',
                              F.when(F.col('name').rlike(MILITARY_REGEX), True)
                              .otherwise(False))

# %%
airports.filter(F.col('military') == True).toPandas()
# Out:
#      faa                             name        lat         lon     alt  tz  \
# 0    ADW                      Andrews Afb  38.810806  -76.867028   280.0  -5
# 1    AGN             Angoon Seaplane Base  57.503611 -134.585000     0.0  -9
# 2    ALZ             Alitak Seaplane Base  56.899444 -154.247778     0.0  -9
# 3    AOS          Amook Bay Seaplane Base  57.471389 -153.815278     0.0  -9
# 4    APG                     Phillips Aaf  39.466219  -76.168808    57.0  -5
# ..   ...                              ...        ...         ...     ...  ..
# 155  WRI                     Mc Guire Afb  40.015556  -74.591667   131.0  -5
# 156  WSD                      Condron Aaf  32.341484 -106.402770  3934.0  -7
# 157  WSJ  San Juan - Uganik Seaplane Base  57.730278 -153.320556     0.0  -9
# 158  WSX          Westsound Seaplane Base  48.617778 -122.952778     0.0  -8
# 159  WWP        North Whale Seaplane Base  56.116389 -133.121667     0.0  -9
#
#     dst         region type  military
# 0     A  MAINLAND-EAST  NaN      True
# 1     A         ALASKA  NaN      True
# 2     A         ALASKA  NaN      True
# 3     A         ALASKA  NaN      True
# 4     A  MAINLAND-EAST  NaN      True
# ..   ..            ...  ...       ...
# 155   A  MAINLAND-EAST  NaN      True
# 156   A  MAINLAND-WEST  NaN      True
# 157   A         ALASKA  NaN      True
# 158   A  MAINLAND-WEST  NaN      True
# 159   A         ALASKA  NaN      True
#
# [160 rows x 10 columns]

# %% [markdown]
# ### Pergunta 7

# %%
INTER = ["International", "Intl", "Intercontinental"]
INTER_REGEX = r'|'.join(map(lambda x : f".*({x}).*", INTER))
INTER_REGEX
# Out:
# '.*(International).*|.*(Intl).*|.*(Intercontinental).*'

# %%
REGIONAL = ["Regional", "Reigonal", "Rgnl", "County", "Metro", "Metropolitan"]
REGIONAL_REGEX = r'|'.join(map(lambda x: f".*({x}).*", REGIONAL))
REGIONAL_REGEX
# Out:
# '.*(Regional).*|.*(Reigonal).*|.*(Rgnl).*|.*(County).*|.*(Metro).*|.*(Metropolitan).*'

# %%
MUNICIPAL = ["Municipal", "Muni", "City"]
MUNICIPAL_REGEX = r'|'.join(map(lambda x: f".*({x}).*", MUNICIPAL))
MUNICIPAL_REGEX
# Out:
# '.*(Municipal).*|.*(Muni).*|.*(City).*'

# %%
airports = airports.withColumn('administration',
                              F.when(F.col('name').rlike(INTER_REGEX), 'I')
                              .when(F.col('name').rlike(r'.*National.*|.*Natl.*'), 'N')
                              .when(F.col('name').rlike(REGIONAL_REGEX), 'R')
                              .when(F.col('name').rlike(MUNICIPAL_REGEX), 'M')
                              .otherwise(float('nan')))

# %%
airports.select('name', 'administration').show(truncate = False)
# Out:
# +------------------------------------+--------------+
# |name                                |administration|
# +------------------------------------+--------------+
# |Lansdowne Airport                   |NaN           |
# |Moton Field Municipal Airport       |M             |
# |Schaumburg Regional                 |R             |
# |Randall Airport                     |NaN           |
# |Jekyll Island Airport               |NaN           |
# |Elizabethton Municipal Airport      |M             |
# |Williams County Airport             |R             |
# |Finger Lakes Regional Airport       |R             |
# |Shoestring Aviation Airfield        |NaN           |
# |Jefferson County Intl               |I             |
# |Harford County Airport              |R             |
# |Galt Field Airport                  |NaN           |
# |Port Bucyrus-Crawford County Airport|R             |
# |Jackson County Airport              |R             |
# |Martin Campbell Field Airport       |NaN           |
# |Mansfield Municipal                 |M             |
# |Frazier Lake Airpark                |NaN           |
# |Clow International Airport          |I             |
# |Kent State Airport                  |NaN           |
# |Fortman Airport                     |NaN           |
# +------------------------------------+--------------+
# only showing top 20 rows

# %% [markdown]
# # Salvando em parquet

# %%
airports.write.parquet(
    mode ='overwrite',
    path = 'C:/Practice_Pyspark/airports_proc/parquet')

# %%
airports_parquet = spark.read.parquet('C:/Practice_Pyspark/airports_proc/parquet')

# %%
airports_parquet.toPandas()
# Out:
#       faa                           name        lat         lon     alt  tz  \
# 0     04G              Lansdowne Airport  41.130472  -80.619583  1044.0  -5
# 1     06A  Moton Field Municipal Airport  32.460572  -85.680028   264.0  -5
# 2     06C            Schaumburg Regional  41.989341  -88.101243   801.0  -6
# 3     06N                Randall Airport  41.431912  -74.391561   523.0  -5
# 4     09J          Jekyll Island Airport  31.074472  -81.427778    11.0  -4
# ...   ...                            ...        ...         ...     ...  ..
# 1392  ZUN                     Black Rock  35.083228 -108.791778  6454.0  -7
# 1393  ZVE         New Haven Rail Station  41.298669  -72.925992     7.0  -5
# 1394  ZWI      Wilmington Amtrak Station  39.736667  -75.551667     0.0  -5
# 1395  ZWU       Washington Union Station  38.897460  -77.006430    76.0  -5
# 1396  ZYP                   Penn Station  40.750500  -73.993500    35.0  -5
#
#      dst         region type  military administration
# 0      A  MAINLAND-EAST   AP     False            NaN
# 1      A  MAINLAND-EAST   AP     False              M
# 2      A  MAINLAND-EAST  NaN     False              R
# 3      A  MAINLAND-EAST   AP     False            NaN
# 4      A  MAINLAND-EAST   AP     False            NaN
# ...   ..            ...  ...       ...            ...
# 1392   A  MAINLAND-WEST  NaN     False            NaN
# 1393   A  MAINLAND-EAST   AS     False            NaN
# 1394   A  MAINLAND-EAST   AS     False            NaN
# 1395   A  MAINLAND-EAST   AS     False            NaN
# 1396   A  MAINLAND-EAST   AS     False            NaN
#
# [1397 rows x 11 columns]

# %% [markdown]
# # Planes

# %%
schema_planes = StructType()\
    .add('tailnum', StringType(), True)\
    .add('year', IntegerType(), True)\
    .add('type', StringType(), True)\
    .add('manufacturer', StringType(), True)\
    .add('model', StringType(), True)\
    .add('engines', IntegerType(), True)\
    .add('seats', IntegerType(), True)\
    .add('speed', IntegerType(), True)\
    .add('engine', StringType(), True)

planes = spark.read.format('csv')\
    .option('header', True)\
    .schema(schema_planes)\
    .load('C:/Practice_Pyspark/planes.csv')

planes.printSchema()
# Out:
# root
#  |-- tailnum: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- type: string (nullable = true)
#  |-- manufacturer: string (nullable = true)
#  |-- model: string (nullable = true)
#  |-- engines: integer (nullable = true)
#  |-- seats: integer (nullable = true)
#  |-- speed: integer (nullable = true)
#  |-- engine: string (nullable = true)

# %% [markdown]
# ### Pergunta 1

# %%
REGEX_TAILCHAR_2 = r'.*([ABCDEFGHJKLMNPQRSTUVWXYZ]{2}$)'
REGEX_TAILCHAR_1 = r'.*([ABCDEFGHJKLMNPQRSTUVWXYZ]$)'

# %%
planes = planes.withColumn('tailchar', 
                          F.when(
                              (F.length(F.col('tailnum')) == 6) & 
                              (F.col('tailnum').rlike(REGEX_TAILCHAR_2)), 
                              F.substring(F.col('tailnum'), 5, 2))
                          .when((F.length(F.col('tailnum')) == 6) & 
                               (F.col('tailnum').rlike(REGEX_TAILCHAR_1)), 
                               F.substring(F.col('tailnum'), 6, 1)))

# %%
planes.filter((F.col('tailchar').isNotNull())).show()
# Out:
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|tailchar|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|       K|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|       P|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|      DE|
# | N121UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N122US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# only showing top 20 rows

# %% [markdown]
# ### Pergunta 2

# %%
planes = planes.withColumn('year',
                          F.when(F.col('year') == 0, 1996)
                          .otherwise(F.col('year')))

# %%
planes.filter(F.col('year') == 1996).show(100)
# Out:
# +-------+----+--------------------+-----------------+-----------+-------+-----+-----+----------+--------+
# |tailnum|year|                type|     manufacturer|      model|engines|seats|speed|    engine|tailchar|
# +-------+----+--------------------+-----------------+-----------+-------+-----+-----+----------+--------+
# | N188DN|1996|Fixed wing multi ...|           BOEING|    767-332|      2|  330| null| Turbo-fan|      DN|
# | N234SW|1996|Fixed wing multi ...|          EMBRAER|  EMB-120ER|      2|   32| null|Turbo-prop|      SW|
# | N235SW|1996|Fixed wing multi ...|          EMBRAER|  EMB-120ER|      2|   32| null|Turbo-prop|      SW|
# | N237SW|1996|Fixed wing multi ...|          EMBRAER|  EMB-120ER|      2|   32| null|Turbo-prop|      SW|
# | N290SW|1996|Fixed wing multi ...|          EMBRAER|  EMB-120ER|      2|   32| null|Turbo-prop|      SW|
# | N291SW|1996|Fixed wing multi ...|          EMBRAER|  EMB-120ER|      2|   32| null|Turbo-prop|      SW|
# | N292SW|1996|Fixed wing multi ...|          EMBRAER|  EMB-120ER|      2|   32| null|Turbo-prop|      SW|
# | N294SW|1996|Fixed wing multi ...|          EMBRAER|  EMB-120ER|      2|   32| null|Turbo-prop|      SW|
# | N295SW|1996|Fixed wing multi ...|          EMBRAER|  EMB-120ER|      2|   32| null|Turbo-prop|      SW|
# | N296SW|1996|Fixed wing multi ...|          EMBRAER|  EMB-120ER|      2|   32| null|Turbo-prop|      SW|
# | N297SW|1996|Fixed wing multi ...|          EMBRAER|  EMB-120ER|      2|   32| null|Turbo-prop|      SW|
# | N298SW|1996|Fixed wing multi ...|          EMBRAER|  EMB-120ER|      2|   32| null|Turbo-prop|      SW|
# | N349NW|1996|Fixed wing multi ...| AIRBUS INDUSTRIE|   A320-212|      2|  182| null| Turbo-fan|      NW|
# | N413SW|1996|Fixed wing multi ...|         CANADAIR|CL-600-2B19|      2|   55| null| Turbo-fan|      SW|
# | N430UA|1996|Fixed wing multi ...| AIRBUS INDUSTRIE|   A320-232|      2|  200| null| Turbo-fan|      UA|
# | N431UA|1996|Fixed wing multi ...| AIRBUS INDUSTRIE|   A320-232|      2|  200| null| Turbo-fan|      UA|
# | N432UA|1996|Fixed wing multi ...| AIRBUS INDUSTRIE|   A320-232|      2|  200| null| Turbo-fan|      UA|
# | N433UA|1996|Fixed wing multi ...| AIRBUS INDUSTRIE|   A320-232|      2|  200| null| Turbo-fan|      UA|
# | N434UA|1996|Fixed wing multi ...| AIRBUS INDUSTRIE|   A320-232|      2|  200| null| Turbo-fan|      UA|
# | N435UA|1996|Fixed wing multi ...| AIRBUS INDUSTRIE|   A320-232|      2|  200| null| Turbo-fan|      UA|
# | N436UA|1996|Fixed wing multi ...| AIRBUS INDUSTRIE|   A320-232|      2|  200| null| Turbo-fan|      UA|
# | N539US|1996|Fixed wing multi ...|           BOEING|    757-251|      2|  178| null| Turbo-jet|      US|
# | N540US|1996|Fixed wing multi ...|           BOEING|    757-251|      2|  178| null| Turbo-jet|      US|
# | N541US|1996|Fixed wing multi ...|           BOEING|    757-251|      2|  178| null| Turbo-jet|      US|
# | N542US|1996|Fixed wing multi ...|           BOEING|    757-251|      2|  178| null| Turbo-jet|      US|
# | N543US|1996|Fixed wing multi ...|           BOEING|    757-251|      2|  178| null| Turbo-jet|      US|
# | N544US|1996|Fixed wing multi ...|           BOEING|    757-251|      2|  178| null| Turbo-jet|      US|
# | N545US|1996|Fixed wing multi ...|           BOEING|    757-251|      2|  178| null| Turbo-jet|      US|
# | N546US|1996|Fixed wing multi ...|           BOEING|    757-251|      2|  178| null| Turbo-jet|      US|
# | N547US|1996|Fixed wing multi ...|           BOEING|    757-251|      2|  178| null| Turbo-jet|      US|
# | N548US|1996|Fixed wing multi ...|           BOEING|    757-251|      2|  178| null| Turbo-jet|      US|
# | N549US|1996|Fixed wing multi ...|           BOEING|    757-251|      2|  178| null| Turbo-jet|      US|
# | N602AW|1996|Fixed wing multi ...| AIRBUS INDUSTRIE|   A320-232|      2|  200| null| Turbo-fan|      AW|
# | N620SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N621SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N622SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N623SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N624SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N625SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N626SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N627SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N628SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N629SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N630WN|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      WN|
# | N631SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N632SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N633SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N634SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N635SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N636WN|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      WN|
# | N637SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N638SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N639SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N640SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N641SW|1996|Fixed wing multi ...|           BOEING|    737-3H4|      2|  149| null| Turbo-fan|      SW|
# | N702TW|1996|Fixed wing multi ...|           BOEING|    757-2Q8|      2|  178| null| Turbo-fan|      TW|
# | N703TW|1996|Fixed wing multi ...|           BOEING|    757-2Q8|      2|  178| null| Turbo-fan|      TW|
# | N912DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-jet|      DN|
# | N913DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-jet|      DN|
# | N914DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-jet|      DN|
# | N915DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-jet|      DN|
# | N916DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-jet|      DN|
# | N929DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-jet|      DN|
# | N930DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-jet|      DN|
# | N932DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-jet|      DN|
# | N934DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-fan|      DN|
# | N935DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-jet|      DN|
# | N936DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-jet|      DN|
# | N939DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-fan|      DN|
# | N947DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-fan|      DN|
# | N948DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-fan|      DN|
# | N954DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-fan|      DN|
# | N955DN|1996|Fixed wing multi ...|MCDONNELL DOUGLAS|   MD-90-30|      2|  142| null| Turbo-fan|      DN|
# +-------+----+--------------------+-----------------+-----------+-------+-----+-----+----------+--------+

# %% [markdown]
# ### Pergunta 3

# %%
from pyspark.sql.window import Window

# %%
win_A = Window.partitionBy(F.col('manufacturer'), F.col('model')).orderBy(F.col('manufacturer'), F.col('model'), F.col('year'))

# %%
planes_s_Null = planes.filter(F.col('year').isNotNull())

# %%
pla_A = planes_s_Null.withColumn("row", F.row_number().over(win_A)) \
  .filter(F.col("row") == 1).drop("row")

# %%
pla_A.show()
# Out:
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|tailchar|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# | N906FR|2002|Fixed wing multi ...|          AIRBUS|A319-111|      2|  147| null|Turbo-fan|      FR|
# | N910FR|2002|Fixed wing multi ...|          AIRBUS|A319-112|      2|  100| null|Turbo-fan|      FR|
# | N338NB|2002|Fixed wing multi ...|          AIRBUS|A319-114|      2|  145| null|Turbo-fan|      NB|
# | N521VA|2006|Fixed wing multi ...|          AIRBUS|A319-115|      2|  147| null|Turbo-fan|      VA|
# | N851UA|2002|Fixed wing multi ...|          AIRBUS|A319-131|      2|  179| null|Turbo-jet|      UA|
# | N833AW|2002|Fixed wing multi ...|          AIRBUS|A319-132|      2|  179| null|Turbo-fan|      AW|
# | N377NW|2003|Fixed wing multi ...|          AIRBUS|A320-211|      2|  182| null|Turbo-fan|      NW|
# | N375NC|2002|Fixed wing multi ...|          AIRBUS|A320-212|      2|  182| null|Turbo-fan|      NC|
# | N219FR|2002|Fixed wing multi ...|          AIRBUS|A320-214|      2|  182| null|Turbo-fan|      FR|
# | N489UA|2002|Fixed wing multi ...|          AIRBUS|A320-232|      2|  200| null|Turbo-fan|      UA|
# | N186US|2002|Fixed wing multi ...|          AIRBUS|A321-211|      2|  199| null|Turbo-fan|      US|
# | N507AY|2008|Fixed wing multi ...|          AIRBUS|A321-231|      2|  379| null|Turbo-fan|      AY|
# | N852NW|2004|Fixed wing multi ...|          AIRBUS|A330-223|      3|  379| null|Turbo-fan|      NW|
# | N380HA|2010|Fixed wing multi ...|          AIRBUS|A330-243|      2|  377| null|Turbo-fan|      HA|
# | N803NW|2003|Fixed wing multi ...|          AIRBUS|A330-323|      2|  379| null|Turbo-fan|      NW|
# | N902FR|2001|Fixed wing multi ...|AIRBUS INDUSTRIE|A319-111|      2|  147| null|Turbo-jet|      FR|
# | N700UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A319-112|      2|  179| null|Turbo-fan|      UW|
# | N301NB|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A319-114|      2|  145| null|Turbo-fan|      NB|
# | N801UA|1997|Fixed wing multi ...|AIRBUS INDUSTRIE|A319-131|      2|  179| null|Turbo-jet|      UA|
# | N801AW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A319-132|      2|  179| null|Turbo-jet|      AW|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# only showing top 20 rows

# %%
planes_A = planes.alias('ori').join(pla_A.alias('cop'), 
                                    (F.col('ori.model') == F.col('cop.model')) & 
                                    (F.col('ori.manufacturer') == F.col('cop.manufacturer')), 'inner')\
    .select(F.col('ori.tailnum'), F.col('ori.year'), F.col('ori.type'), F.col('ori.manufacturer'), F.col('ori.model'),\
           F.col('ori.engines'), F.col('ori.seats'), F.col('ori.speed'), F.col('ori.engine'), F.col('ori.tailchar'),\
           F.col('cop.year').alias('year_fill'))

# %%
planes_A.filter(F.col('year').isNull()).show()
# Out:
# +-------+----+--------------------+----------------+-----------+-------+-----+-----+---------+--------+---------+
# |tailnum|year|                type|    manufacturer|      model|engines|seats|speed|   engine|tailchar|year_fill|
# +-------+----+--------------------+----------------+-----------+-------+-----+-----+---------+--------+---------+
# | N174US|null|Fixed wing multi ...|AIRBUS INDUSTRIE|   A321-211|      2|  199| null|Turbo-jet|      US|     2001|
# | N177US|null|Fixed wing multi ...|AIRBUS INDUSTRIE|   A321-211|      2|  199| null|Turbo-jet|      US|     2001|
# | N181UW|null|Fixed wing multi ...|AIRBUS INDUSTRIE|   A321-211|      2|  199| null|Turbo-jet|      UW|     2001|
# | N194UW|null|Fixed wing multi ...|          AIRBUS|   A321-211|      2|  199| null|Turbo-fan|      UW|     2002|
# | N271LV|null|Fixed wing multi ...|          BOEING|    737-705|      2|  149| null|Turbo-fan|      LV|     1998|
# | N298WN|null|Fixed wing multi ...|          BOEING|    737-7H4|      2|  140| null|Turbo-fan|      WN|     1997|
# | N299WN|null|Fixed wing multi ...|          BOEING|    737-7H4|      2|  140| null|Turbo-fan|      WN|     1997|
# | N331NB|null|Fixed wing multi ...|AIRBUS INDUSTRIE|   A319-114|      2|  145| null|Turbo-fan|      NB|     1999|
# | N33292|null|Fixed wing multi ...|          BOEING|    737-824|      2|  149| null|Turbo-fan|    null|     1998|
# | N345NB|null|Fixed wing multi ...|          AIRBUS|   A319-114|      2|  145| null|Turbo-fan|      NB|     2002|
# | N389HA|null|Fixed wing multi ...|          AIRBUS|   A330-243|      2|  377| null|Turbo-fan|      HA|     2010|
# | N466UA|null|Fixed wing multi ...|AIRBUS INDUSTRIE|   A320-232|      2|  200| null|Turbo-fan|      UA|     1993|
# | N527AS|null|Fixed wing multi ...|          BOEING|    737-890|      2|  149| null|Turbo-fan|      AS|     2005|
# | N53441|null|Fixed wing multi ...|          BOEING|  737-924ER|      2|  191| null|Turbo-fan|    null|     2008|
# | N583HA|null|Fixed wing multi ...|          BOEING|    767-33A|      2|  330| null|Turbo-fan|      HA|     2001|
# | N613QX|null|Fixed wing multi ...|  BOMBARDIER INC|CL-600-2C10|      2|   80| null|Turbo-fan|      QX|     1999|
# | N673AW|null|Fixed wing multi ...|          AIRBUS|   A320-232|      2|  200| null|Turbo-fan|      AW|     2002|
# | N679SA|null|Fixed wing multi ...|  BOMBARDIER INC|CL-600-2B19|      2|   55| null|Turbo-fan|      SA|     1999|
# | N729JB|null|Fixed wing multi ...|          AIRBUS|   A320-232|      2|  200| null|Turbo-fan|      JB|     2002|
# | N73278|null|Fixed wing multi ...|          BOEING|    737-824|      2|  149| null|Turbo-fan|    null|     1998|
# +-------+----+--------------------+----------------+-----------+-------+-----+-----+---------+--------+---------+
# only showing top 20 rows

# %%
planes_A = planes_A.withColumn('year', 
                              F.coalesce(F.col('year'), F.col('year_fill'))).drop(F.col('year_fill'))

# %%
planes_A.show()
# Out:
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|tailchar|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|    null|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|       K|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|       P|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|    null|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|      DE|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+
# only showing top 20 rows

# %% [markdown]
# ### Pergunta 4

# %%
planes_A = planes_A.withColumn('age',
                          F.when(F.col('year').isNotNull(), 
                                 F.date_format(F.current_date(), 'yyyy') - F.col('year')).cast('int'))

# %%
planes_A.filter(F.col('age').isNotNull()).show()
# Out:
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+---+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|tailchar|age|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+---+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW| 24|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|    null| 22|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      UW| 22|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US| 22|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      US| 22|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|       K| 24|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|       P| 24|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|    null| 27|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|      DE| 35|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+--------+---+
# only showing top 20 rows

# %% [markdown]
# ### Pergunta 5

# %%
TYPE = ["Fixed wing multi engine", "Fixed wing single engine", "Rotorcraft"]

# %%
planes_A = planes_A.withColumn('type',
                          F.when(F.col('type') == TYPE[0], 'MULTI_ENG')
                          .when(F.col('type') == TYPE[1], 'SINGLE_ENG')
                          .when(F.col('type') == TYPE[2], 'ROTORCRAFT'))

# %%
planes_A.filter(F.col('type') != 'MULTI_ENG').show()
# Out:
# +-------+----+----------+--------------------+----------+-------+-----+-----+-------------+--------+---+
# |tailnum|year|      type|        manufacturer|     model|engines|seats|speed|       engine|tailchar|age|
# +-------+----+----------+--------------------+----------+-------+-----+-----+-------------+--------+---+
# | N201AA|1959|SINGLE_ENG|              CESSNA|       150|      1|    2|   90|Reciprocating|      AA| 63|
# | N347AA|1985|ROTORCRAFT|            SIKORSKY|     S-76A|      2|   14| null|  Turbo-shaft|      AA| 37|
# | N425AA|1968|SINGLE_ENG|               PIPER| PA-28-180|      1|    4|  107|Reciprocating|      AA| 54|
# | N508AA|1975|ROTORCRAFT|                BELL|      206B|      1|    5|  112|  Turbo-shaft|      AA| 47|
# | N508JB|2007|SINGLE_ENG|  CIRRUS DESIGN CORP|      SR22|      1|    4| null|Reciprocating|      JB| 15|
# | N520AA|1985|SINGLE_ENG|        KILDALL GARY| FALCON-XP|      1|    2| null|Reciprocating|      AA| 37|
# | N537JB|2012|ROTORCRAFT|ROBINSON HELICOPT...|       R66|      1|    5| null|  Turbo-shaft|      JB| 10|
# | N545AA|1976|SINGLE_ENG|               PIPER|PA-32R-300|      1|    7|  126|Reciprocating|      AA| 46|
# | N557AA|1993|SINGLE_ENG|          MARZ BARRY| KITFOX IV|      1|    2| null|Reciprocating|      AA| 29|
# | N575AA|1963|SINGLE_ENG|              CESSNA|210-5(205)|      1|    6| null|Reciprocating|      AA| 59|
# | N621AA|1975|SINGLE_ENG|              CESSNA|      172M|      1|    4|  108|      4 Cycle|      AA| 47|
# +-------+----+----------+--------------------+----------+-------+-----+-----+-------------+--------+---+

# %% [markdown]
# ### Pergunta 6

# %%
MANUFACTURER = ['AIRBUS', 'BOEING', 'BOMBARDIER', 'CESSNA', 'EMBRAER', 'SIKORSKY', 'CANADAIR', 'PIPER', 'MCDONNELL DOUGLAS',
                'CIRRUS', 'BELL', 'KILDALL GARY', 'LAMBERT RICHARD', 'BARKER JACK', 'ROBINSON HELICOPTER', 'GULFSTREAM'
                'MARZ BARRY']

print(len(MANUFACTURER))
# Out:
# 16

# %%
planes_A = planes_A.withColumn('manufacturer',
                           F.when(F.col('manufacturer').contains(MANUFACTURER[0]), MANUFACTURER[0])
                          .when(F.col('manufacturer').contains(MANUFACTURER[1]), MANUFACTURER[1])
                          .when(F.col('manufacturer').contains(MANUFACTURER[2]), MANUFACTURER[2])
                          .when(F.col('manufacturer').contains(MANUFACTURER[3]), MANUFACTURER[3])
                          .when(F.col('manufacturer').contains(MANUFACTURER[4]), MANUFACTURER[4])
                          .when(F.col('manufacturer').contains(MANUFACTURER[5]), MANUFACTURER[5])
                          .when(F.col('manufacturer').contains(MANUFACTURER[6]), MANUFACTURER[6])
                          .when(F.col('manufacturer').contains(MANUFACTURER[7]), MANUFACTURER[7])
                          .when(F.col('manufacturer').contains(MANUFACTURER[8]), MANUFACTURER[8])
                          .when(F.col('manufacturer').contains(MANUFACTURER[9]), MANUFACTURER[9])
                          .when(F.col('manufacturer').contains(MANUFACTURER[10]), MANUFACTURER[10])
                          .when(F.col('manufacturer').contains(MANUFACTURER[11]), MANUFACTURER[11])
                          .when(F.col('manufacturer').contains(MANUFACTURER[12]), MANUFACTURER[12])
                          .when(F.col('manufacturer').contains(MANUFACTURER[13]), MANUFACTURER[13])
                          .when(F.col('manufacturer').contains(MANUFACTURER[14]), MANUFACTURER[14])
                          .when(F.col('manufacturer').contains(MANUFACTURER[15]), MANUFACTURER[15]))

# %%
planes_A.show()
# Out:
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+
# |tailnum|year|     type|manufacturer|   model|engines|seats|speed|   engine|tailchar|age|
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+
# | N102UW|1998|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 24|
# | N103US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N104UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N105UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N107US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N108UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N109UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N110UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N111US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N11206|2000|MULTI_ENG|      BOEING| 737-824|      2|  149| null|Turbo-fan|    null| 22|
# | N112US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N113UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N114UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N117UW|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 22|
# | N118US|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 22|
# | N119US|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 22|
# | N1200K|1998|MULTI_ENG|      BOEING| 767-332|      2|  330| null|Turbo-fan|       K| 24|
# | N1201P|1998|MULTI_ENG|      BOEING| 767-332|      2|  330| null|Turbo-fan|       P| 24|
# | N12114|1995|MULTI_ENG|      BOEING| 757-224|      2|  178| null|Turbo-jet|    null| 27|
# | N121DE|1987|MULTI_ENG|      BOEING| 767-332|      2|  330| null|Turbo-fan|      DE| 35|
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+
# only showing top 20 rows

# %% [markdown]
# ### Pergunta 7

# %%
planes_A = planes_A.withColumn('model', 
                               F.regexp_replace('model', r'[(].*[)]', ''))

# %%
planes_A.show()
# Out:
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+
# |tailnum|year|     type|manufacturer|   model|engines|seats|speed|   engine|tailchar|age|
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+
# | N102UW|1998|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 24|
# | N103US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N104UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N105UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N107US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N108UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N109UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N110UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N111US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N11206|2000|MULTI_ENG|      BOEING| 737-824|      2|  149| null|Turbo-fan|    null| 22|
# | N112US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N113UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N114UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N117UW|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 22|
# | N118US|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 22|
# | N119US|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 22|
# | N1200K|1998|MULTI_ENG|      BOEING| 767-332|      2|  330| null|Turbo-fan|       K| 24|
# | N1201P|1998|MULTI_ENG|      BOEING| 767-332|      2|  330| null|Turbo-fan|       P| 24|
# | N12114|1995|MULTI_ENG|      BOEING| 757-224|      2|  178| null|Turbo-jet|    null| 27|
# | N121DE|1987|MULTI_ENG|      BOEING| 767-332|      2|  330| null|Turbo-fan|      DE| 35|
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+
# only showing top 20 rows

# %% [markdown]
# ### Pergunta 8

# %%
planes_A.filter(F.col('speed').isNull()).show()
# Out:
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+
# |tailnum|year|     type|manufacturer|   model|engines|seats|speed|   engine|tailchar|age|
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+
# | N102UW|1998|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 24|
# | N103US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N104UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N105UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N107US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N108UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N109UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N110UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N111US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N11206|2000|MULTI_ENG|      BOEING| 737-824|      2|  149| null|Turbo-fan|    null| 22|
# | N112US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 23|
# | N113UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N114UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 23|
# | N117UW|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      UW| 22|
# | N118US|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 22|
# | N119US|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182| null|Turbo-fan|      US| 22|
# | N1200K|1998|MULTI_ENG|      BOEING| 767-332|      2|  330| null|Turbo-fan|       K| 24|
# | N1201P|1998|MULTI_ENG|      BOEING| 767-332|      2|  330| null|Turbo-fan|       P| 24|
# | N12114|1995|MULTI_ENG|      BOEING| 757-224|      2|  178| null|Turbo-jet|    null| 27|
# | N121DE|1987|MULTI_ENG|      BOEING| 767-332|      2|  330| null|Turbo-fan|      DE| 35|
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+
# only showing top 20 rows

# %%
planes_A = planes_A.withColumn('speed',
                              F.when(F.col('speed').isNull(), F.ceil(F.col('seats') / 0.36).cast('int'))
                              .otherwise(F.col('speed')))

# %%
planes_A.show()
# Out:
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+
# |tailnum|year|     type|manufacturer|   model|engines|seats|speed|   engine|tailchar|age|
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+
# | N102UW|1998|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 24|
# | N103US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      US| 23|
# | N104UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 23|
# | N105UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 23|
# | N107US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      US| 23|
# | N108UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 23|
# | N109UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 23|
# | N110UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 23|
# | N111US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      US| 23|
# | N11206|2000|MULTI_ENG|      BOEING| 737-824|      2|  149|  414|Turbo-fan|    null| 22|
# | N112US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      US| 23|
# | N113UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 23|
# | N114UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 23|
# | N117UW|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 22|
# | N118US|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      US| 22|
# | N119US|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      US| 22|
# | N1200K|1998|MULTI_ENG|      BOEING| 767-332|      2|  330|  917|Turbo-fan|       K| 24|
# | N1201P|1998|MULTI_ENG|      BOEING| 767-332|      2|  330|  917|Turbo-fan|       P| 24|
# | N12114|1995|MULTI_ENG|      BOEING| 757-224|      2|  178|  495|Turbo-jet|    null| 27|
# | N121DE|1987|MULTI_ENG|      BOEING| 767-332|      2|  330|  917|Turbo-fan|      DE| 35|
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+
# only showing top 20 rows

# %% [markdown]
# ### Pergunta 9

# %%
ENGINE_TYPE = ["Turbo-fan", "Turbo-jet", "Turbo-prop", "Turbo-shaft", "4 Cycle"]

# %%
planes_A = planes_A.withColumn('engine_type',
                              F.when(F.col('engine') == ENGINE_TYPE[0], 'FAN')
                              .when(F.col('engine') == ENGINE_TYPE[1], 'JET')
                              .when(F.col('engine') == ENGINE_TYPE[2], 'PROP')
                              .when(F.col('engine') == ENGINE_TYPE[3], 'SHAFT')
                              .when(F.col('engine') == ENGINE_TYPE[4], 'CYCLE'))

# %%
planes_A.show()
# Out:
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+-----------+
# |tailnum|year|     type|manufacturer|   model|engines|seats|speed|   engine|tailchar|age|engine_type|
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+-----------+
# | N102UW|1998|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 24|        FAN|
# | N103US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      US| 23|        FAN|
# | N104UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 23|        FAN|
# | N105UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 23|        FAN|
# | N107US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      US| 23|        FAN|
# | N108UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 23|        FAN|
# | N109UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 23|        FAN|
# | N110UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 23|        FAN|
# | N111US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      US| 23|        FAN|
# | N11206|2000|MULTI_ENG|      BOEING| 737-824|      2|  149|  414|Turbo-fan|    null| 22|        FAN|
# | N112US|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      US| 23|        FAN|
# | N113UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 23|        FAN|
# | N114UW|1999|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 23|        FAN|
# | N117UW|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      UW| 22|        FAN|
# | N118US|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      US| 22|        FAN|
# | N119US|2000|MULTI_ENG|      AIRBUS|A320-214|      2|  182|  506|Turbo-fan|      US| 22|        FAN|
# | N1200K|1998|MULTI_ENG|      BOEING| 767-332|      2|  330|  917|Turbo-fan|       K| 24|        FAN|
# | N1201P|1998|MULTI_ENG|      BOEING| 767-332|      2|  330|  917|Turbo-fan|       P| 24|        FAN|
# | N12114|1995|MULTI_ENG|      BOEING| 757-224|      2|  178|  495|Turbo-jet|    null| 27|        JET|
# | N121DE|1987|MULTI_ENG|      BOEING| 767-332|      2|  330|  917|Turbo-fan|      DE| 35|        FAN|
# +-------+----+---------+------------+--------+-------+-----+-----+---------+--------+---+-----------+
# only showing top 20 rows

# %%
planes_A.write.parquet(
    mode ='overwrite',
    path = 'C:/Practice_Pyspark/planes_proc/parquet')

# %% [markdown]
# # Flights

# %%
schema_flights = StructType()\
    .add('year', IntegerType(), True)\
    .add('month', IntegerType(), True)\
    .add('day', IntegerType(), True)\
    .add('dep_time', StringType(), True)\
    .add('dep_delay', StringType(), True)\
    .add('arr_time', StringType(), True)\
    .add('arr_delay', StringType(), True)\
    .add('carrier', StringType(), True)\
    .add('tailnum', StringType(), True)\
    .add('flight', StringType(), True)\
    .add('origin', StringType(), True)\
    .add('dest', StringType(), True)\
    .add('air_time', IntegerType(), True)\
    .add('distance', IntegerType(), True)\
    .add('hour', IntegerType(), True)\
    .add('minute', IntegerType(), True)

flights = spark.read.format('csv')\
    .option('header', True)\
    .schema(schema_flights)\
    .load('C:/Practice_Pyspark/flights.csv')

flights.printSchema()
# Out:
# root
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- dep_time: string (nullable = true)
#  |-- dep_delay: string (nullable = true)
#  |-- arr_time: string (nullable = true)
#  |-- arr_delay: string (nullable = true)
#  |-- carrier: string (nullable = true)
#  |-- tailnum: string (nullable = true)
#  |-- flight: string (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- dest: string (nullable = true)
#  |-- air_time: integer (nullable = true)
#  |-- distance: integer (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- minute: integer (nullable = true)

# %% [markdown]
# ### Pergunta 1

# %%
flights = flights.withColumn('hour',
                            F.when(F.col('hour').isNull(), 0)
                            .otherwise(F.col('hour')))

# %%
flights = flights.withColumn('minute',
                            F.when(F.col('minute').isNull(), 0)
                            .otherwise(F.col('minute')))

# %%
flights.select('minute').distinct().show(60)
# Out:
# +------+
# |minute|
# +------+
# |    31|
# |    53|
# |    34|
# |    28|
# |    26|
# |    27|
# |    44|
# |    12|
# |    22|
# |    47|
# |     1|
# |    52|
# |    13|
# |    16|
# |     6|
# |     3|
# |    40|
# |    20|
# |    57|
# |    54|
# |    48|
# |     5|
# |    19|
# |    41|
# |    43|
# |    15|
# |    37|
# |     9|
# |    17|
# |    35|
# |    55|
# |     4|
# |    59|
# |     8|
# |    23|
# |    39|
# |    49|
# |     7|
# |    51|
# |    10|
# |    50|
# |    45|
# |    38|
# |    25|
# |    24|
# |    29|
# |    21|
# |    32|
# |    56|
# |    58|
# |    11|
# |    33|
# |    14|
# |    42|
# |     2|
# |    30|
# |    46|
# |     0|
# |    18|
# |    36|
# +------+

# %% [markdown]
# ### Pergunta 2

# %%
flights.filter(F.col('hour') == 24).show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+
# |2014|    6| 20|    2400|       10|     535|        0|     AA| N3GHAA|  2486|   SEA| ORD|     197|    1721|  24|     0|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+

# %%
flights = flights.withColumn('hour',
                            F.when(F.col('hour') == 24, 0)
                            .otherwise(F.col('hour')))

# %%
flights.filter(F.col('hour') == 24).show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+

# %% [markdown]
# ### Pergunta 3

# %%
def time_10(time):
    return F.col(time) < 10

def string_10(time):
    return F.concat(F.lit('0'), F.col(time).cast(StringType()))

# %%
flights = flights.withColumn('month_s',
                   F.when(time_10('month'), string_10('month'))
                  .otherwise(F.col('month').cast(StringType())))

flights.show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+-------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|month_s|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+-------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA| LAX|     132|     954|   6|    58|     12|
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA| HNL|     360|    2677|  10|    40|     01|
# |2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA| SFO|     111|     679|  14|    43|     03|
# |2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX| SJC|      83|     569|  17|     5|     04|
# |2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA| BUR|     127|     937|   7|    54|     03|
# |2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX| DEN|     121|     991|  10|    37|     01|
# |2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX| OAK|      90|     543|   8|    47|     07|
# |2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA| SFO|      98|     679|  16|    55|     05|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA| SAN|     135|    1050|  12|    36|     04|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA| ORD|     198|    1721|  18|    12|     11|
# |2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA| LAX|     130|     954|  16|    53|     11|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA| PHX|     154|    1107|  11|    20|     08|
# |2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA| LAS|     127|     867|   8|    11|     10|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA| ANC|     183|    1448|  23|    46|     11|
# |2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA| SFO|     129|     679|  13|    14|     10|
# |2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX| SFO|      90|     550|  20|     9|     01|
# |2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA| SMF|      76|     605|  20|    15|     12|
# |2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA| MDW|     216|    1733|  10|    17|     08|
# |2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA| BOS|     290|    2496|  21|    56|     01|
# |2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX| BUR|     111|     817|  17|    33|     06|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+-------+
# only showing top 20 rows

# %%
flights = flights.withColumn('day_s',
                   F.when(time_10('day'), string_10('day'))
                  .otherwise(F.col('day').cast(StringType())))

# %%
flights = flights.withColumn('hour_s',
                   F.when(time_10('hour'), string_10('hour'))
                  .otherwise(F.col('hour').cast(StringType())))

# %%
flights = flights.withColumn('minute_s',
                   F.when(time_10('minute'), string_10('minute'))
                  .otherwise(F.col('minute').cast(StringType())))

# %%
flights.toPandas()
# Out:
#       year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0     2014     12    8      658        -7      935        -5      VX  N846VA
# 1     2014      1   22     1040         5     1505         5      AS  N559AS
# 2     2014      3    9     1443        -2     1652         2      VX  N847VA
# 3     2014      4    9     1705        45     1839        34      WN  N360SW
# 4     2014      3    9      754        -1     1015         1      AS  N612AS
# ...    ...    ...  ...      ...       ...      ...       ...     ...     ...
# 9995  2014      6   23     1806        -4     2104        -6      OO  N225AG
# 9996  2014      8   31     2336        11      452       -13      AA  N3LEAA
# 9997  2014      8    8      904        -1     1042        -5      AS  N523AS
# 9998  2014      8   29     1441        26     1820        10      WN  N8647A
# 9999  2014      7   13     1702        -3     1950       -10      DL  N583NW
#
#      flight origin dest  air_time  distance  hour  minute month_s day_s  \
# 0      1780    SEA  LAX     132.0       954     6      58      12    08
# 1       851    SEA  HNL     360.0      2677    10      40      01    22
# 2       755    SEA  SFO     111.0       679    14      43      03    09
# 3       344    PDX  SJC      83.0       569    17       5      04    09
# 4       522    SEA  BUR     127.0       937     7      54      03    09
# ...     ...    ...  ...       ...       ...   ...     ...     ...   ...
# 9995   3458    SEA  SLC      89.0       689    18       6      06    23
# 9996   1230    SEA  DFW     178.0      1660    23      36      08    31
# 9997    360    SEA  SMF      81.0       605     9       4      08    08
# 9998   2857    SEA  ABQ     133.0      1180    14      41      08    29
# 9999   2237    SEA  HNL     332.0      2677    17       2      07    13
#
#      hour_s minute_s
# 0        06       58
# 1        10       40
# 2        14       43
# 3        17       05
# 4        07       54
# ...     ...      ...
# 9995     18       06
# 9996     23       36
# 9997     09       04
# 9998     14       41
# 9999     17       02
#
# [10000 rows x 20 columns]

# %%
flights = flights.withColumn('timestamp_s', 
                            F.concat(F.col('year').cast(StringType()), F.col('month_s'),
                                     F.col('day_s'), F.col('hour_s'), F.col('minute_s'), F.lit('00')))

# %%
flights.toPandas()
# Out:
#       year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0     2014     12    8      658        -7      935        -5      VX  N846VA
# 1     2014      1   22     1040         5     1505         5      AS  N559AS
# 2     2014      3    9     1443        -2     1652         2      VX  N847VA
# 3     2014      4    9     1705        45     1839        34      WN  N360SW
# 4     2014      3    9      754        -1     1015         1      AS  N612AS
# ...    ...    ...  ...      ...       ...      ...       ...     ...     ...
# 9995  2014      6   23     1806        -4     2104        -6      OO  N225AG
# 9996  2014      8   31     2336        11      452       -13      AA  N3LEAA
# 9997  2014      8    8      904        -1     1042        -5      AS  N523AS
# 9998  2014      8   29     1441        26     1820        10      WN  N8647A
# 9999  2014      7   13     1702        -3     1950       -10      DL  N583NW
#
#      flight  ... dest air_time  distance  hour  minute  month_s day_s hour_s  \
# 0      1780  ...  LAX    132.0       954     6      58       12    08     06
# 1       851  ...  HNL    360.0      2677    10      40       01    22     10
# 2       755  ...  SFO    111.0       679    14      43       03    09     14
# 3       344  ...  SJC     83.0       569    17       5       04    09     17
# 4       522  ...  BUR    127.0       937     7      54       03    09     07
# ...     ...  ...  ...      ...       ...   ...     ...      ...   ...    ...
# 9995   3458  ...  SLC     89.0       689    18       6       06    23     18
# 9996   1230  ...  DFW    178.0      1660    23      36       08    31     23
# 9997    360  ...  SMF     81.0       605     9       4       08    08     09
# 9998   2857  ...  ABQ    133.0      1180    14      41       08    29     14
# 9999   2237  ...  HNL    332.0      2677    17       2       07    13     17
#
#      minute_s     timestamp_s
# 0          58  20141208065800
# 1          40  20140122104000
# 2          43  20140309144300
# 3          05  20140409170500
# 4          54  20140309075400
# ...       ...             ...
# 9995       06  20140623180600
# 9996       36  20140831233600
# 9997       04  20140808090400
# 9998       41  20140829144100
# 9999       02  20140713170200
#
# [10000 rows x 21 columns]

# %%
flights = flights.withColumn('dep_datetime', 
                  F.to_timestamp('timestamp_s', 'yyyyMMddHHmmss'))\
.drop('month_s', 'day_s', 'hour_s', 'minute_s', 'timestamp_s')

# %%
flights.printSchema()
# Out:
# root
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- dep_time: string (nullable = true)
#  |-- dep_delay: string (nullable = true)
#  |-- arr_time: string (nullable = true)
#  |-- arr_delay: string (nullable = true)
#  |-- carrier: string (nullable = true)
#  |-- tailnum: string (nullable = true)
#  |-- flight: string (nullable = true)
#  |-- origin: string (nullable = true)
#  |-- dest: string (nullable = true)
#  |-- air_time: integer (nullable = true)
#  |-- distance: integer (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- minute: integer (nullable = true)
#  |-- dep_datetime: timestamp (nullable = true)

# %%
flights.select('flight', 'dep_datetime').show()
# Out:
# +------+-------------------+
# |flight|       dep_datetime|
# +------+-------------------+
# |  1780|2014-12-08 06:58:00|
# |   851|2014-01-22 10:40:00|
# |   755|2014-03-09 14:43:00|
# |   344|2014-04-09 17:05:00|
# |   522|2014-03-09 07:54:00|
# |    48|2014-01-15 10:37:00|
# |  1520|2014-07-02 08:47:00|
# |   755|2014-05-12 16:55:00|
# |   490|2014-04-19 12:36:00|
# |    26|2014-11-19 18:12:00|
# |   448|2014-11-08 16:53:00|
# |   656|2014-08-03 11:20:00|
# |   608|2014-10-30 08:11:00|
# |   121|2014-11-12 23:46:00|
# |   306|2014-10-31 13:14:00|
# |  1458|2014-01-29 20:09:00|
# |   368|2014-12-17 20:15:00|
# |   827|2014-08-11 10:17:00|
# |    24|2014-01-13 21:56:00|
# |  3488|2014-06-05 17:33:00|
# +------+-------------------+
# only showing top 20 rows

# %%
#f"{F.col('year')}-{F.col('month'):02d}-{F.col('day'):02d} {F.col('hour'):02d}:{F.col('minute'):02d}:00".strftime("....")

# %%
#F.make_timestamp

# %% [markdown]
# ### Pergunta 4

# %%
flights.filter(F.col('dep_time') == 'NA').show(50)
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+-------------------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|       dep_datetime|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+-------------------+
# |2014|    3|  4|      NA|       NA|      NA|       NA|     UA|     NA|   156|   SEA| DEN|    null|    1024|   0|     0|2014-03-04 00:00:00|
# |2014|    2| 12|      NA|       NA|      NA|       NA|     AS| N527AS|     2|   SEA| DCA|    null|    2329|   0|     0|2014-02-12 00:00:00|
# |2014|    7|  1|      NA|       NA|      NA|       NA|     WN| N8323C|  2485|   SEA| MDW|    null|    1733|   0|     0|2014-07-01 00:00:00|
# |2014|    4| 30|      NA|       NA|      NA|       NA|     AS| N526AS|   566|   PDX| LAX|    null|     834|   0|     0|2014-04-30 00:00:00|
# |2014|    1|  3|      NA|       NA|      NA|       NA|     US|     NA|   553|   SEA| PHL|    null|    2378|   0|     0|2014-01-03 00:00:00|
# |2014|    8|  7|      NA|       NA|      NA|       NA|     AS| N579AS|   867|   SEA| OGG|    null|    2640|   0|     0|2014-08-07 00:00:00|
# |2014|    8| 11|      NA|       NA|      NA|       NA|     OO| N689CA|  4528|   PDX| SEA|    null|     129|   0|     0|2014-08-11 00:00:00|
# |2014|    1|  2|      NA|       NA|      NA|       NA|     UA|     NA|   212|   SEA| EWR|    null|    2402|   0|     0|2014-01-02 00:00:00|
# |2014|    5| 15|      NA|       NA|      NA|       NA|     OO| N917SW|  6250|   PDX| LAX|    null|     834|   0|     0|2014-05-15 00:00:00|
# |2014|    2|  7|      NA|       NA|      NA|       NA|     OO| N594SW|  5553|   PDX| SFO|    null|     550|   0|     0|2014-02-07 00:00:00|
# |2014|    6|  6|      NA|       NA|      NA|       NA|     WN| N645SW|   956|   PDX| OAK|    null|     543|   0|     0|2014-06-06 00:00:00|
# |2014|    1|  5|      NA|       NA|      NA|       NA|     UA|     NA|   758|   PDX| IAH|    null|    1825|   0|     0|2014-01-05 00:00:00|
# |2014|    1|  6|      NA|       NA|      NA|       NA|     UA|     NA|  1729|   SEA| DEN|    null|    1024|   0|     0|2014-01-06 00:00:00|
# |2014|    3| 30|      NA|       NA|      NA|       NA|     US|     NA|   500|   SEA| PHX|    null|    1107|   0|     0|2014-03-30 00:00:00|
# |2014|    2|  9|      NA|       NA|      NA|       NA|     OO| N580SW|  5438|   PDX| EUG|    null|     106|   0|     0|2014-02-09 00:00:00|
# |2014|    2|  9|      NA|       NA|      NA|       NA|     OO| N297SW|  5342|   SEA| PDX|    null|     129|   0|     0|2014-02-09 00:00:00|
# |2014|    1|  1|      NA|       NA|      NA|       NA|     OO| N295SW|  5403|   PDX| EUG|    null|     106|   0|     0|2014-01-01 00:00:00|
# |2014|    2| 17|      NA|       NA|      NA|       NA|     AA| N3LCAA|  1236|   SEA| ORD|    null|    1721|   0|     0|2014-02-17 00:00:00|
# |2014|    1|  5|      NA|       NA|      NA|       NA|     UA|     NA|   995|   PDX| SFO|    null|     550|   0|     0|2014-01-05 00:00:00|
# |2014|    5| 26|      NA|       NA|      NA|       NA|     UA|     NA|   690|   SEA| ORD|    null|    1721|   0|     0|2014-05-26 00:00:00|
# |2014|    6| 20|      NA|       NA|      NA|       NA|     UA|     NA|  1142|   SEA| IAH|    null|    1874|   0|     0|2014-06-20 00:00:00|
# |2014|    8| 10|      NA|       NA|      NA|       NA|     OO| N689CA|  4528|   PDX| SEA|    null|     129|   0|     0|2014-08-10 00:00:00|
# |2014|    2| 16|      NA|       NA|      NA|       NA|     UA|     NA|  1523|   SEA| SFO|    null|     679|   0|     0|2014-02-16 00:00:00|
# |2014|   11| 13|      NA|       NA|      NA|       NA|     OO| N617QX|  4825|   PDX| SEA|    null|     129|   0|     0|2014-11-13 00:00:00|
# |2014|    4| 25|      NA|       NA|      NA|       NA|     OO| N216AG|  3478|   PDX| LGB|    null|     846|   0|     0|2014-04-25 00:00:00|
# |2014|    1| 28|      NA|       NA|      NA|       NA|     DL| N3744F|  2482|   PDX| ATL|    null|    2172|   0|     0|2014-01-28 00:00:00|
# |2014|    1|  6|      NA|       NA|      NA|       NA|     B6| N805JB|   598|   SEA| BOS|    null|    2496|   0|     0|2014-01-06 00:00:00|
# |2014|    1|  4|      NA|       NA|      NA|       NA|     WN| N400WN|  4174|   SEA| DEN|    null|    1024|   0|     0|2014-01-04 00:00:00|
# |2014|    9| 24|      NA|       NA|      NA|       NA|     OO| N983CA|  5197|   PDX| SFO|    null|     550|   0|     0|2014-09-24 00:00:00|
# |2014|    7|  3|      NA|       NA|      NA|       NA|     OO| N953SW|  5210|   PDX| SFO|    null|     550|   0|     0|2014-07-03 00:00:00|
# |2014|    2|  9|      NA|       NA|      NA|       NA|     OO| N580SW|  5433|   SEA| PDX|    null|     129|   0|     0|2014-02-09 00:00:00|
# |2014|   12| 16|      NA|       NA|      NA|       NA|     OO| N963SW|  5197|   PDX| SFO|    null|     550|   0|     0|2014-12-16 00:00:00|
# |2014|    9| 26|      NA|       NA|      NA|       NA|     AS| N514AS|   686|   PDX| ORD|    null|    1739|   0|     0|2014-09-26 00:00:00|
# |2014|    2|  4|      NA|       NA|      NA|       NA|     DL| N721TW|   182|   SEA| JFK|    null|    2422|   0|     0|2014-02-04 00:00:00|
# |2014|    1| 18|      NA|       NA|      NA|       NA|     OO| N568SW|  5379|   PDX| SEA|    null|     129|   0|     0|2014-01-18 00:00:00|
# |2014|    1|  5|      NA|       NA|      NA|       NA|     UA|     NA|  1599|   SEA| ORD|    null|    1721|   0|     0|2014-01-05 00:00:00|
# |2014|    8| 16|      NA|       NA|      NA|       NA|     UA|     NA|  1752|   SEA| SFO|    null|     679|   0|     0|2014-08-16 00:00:00|
# |2014|   10|  2|      NA|       NA|      NA|       NA|     WN| N8647A|   827|   SEA| MDW|    null|    1733|   0|     0|2014-10-02 00:00:00|
# |2014|    1|  5|      NA|       NA|      NA|       NA|     UA|     NA|   732|   SEA| ORD|    null|    1721|   0|     0|2014-01-05 00:00:00|
# |2014|    2| 16|      NA|       NA|      NA|       NA|     US|     NA|   614|   SEA| PHX|    null|    1107|   0|     0|2014-02-16 00:00:00|
# |2014|    2| 27|      NA|       NA|      NA|       NA|     OO| N946SW|  5196|   PDX| SFO|    null|     550|   0|     0|2014-02-27 00:00:00|
# |2014|    2|  9|      NA|       NA|      NA|       NA|     AS| N627AS|   682|   SEA| DEN|    null|    1024|   0|     0|2014-02-09 00:00:00|
# |2014|    1| 30|      NA|       NA|      NA|       NA|     WN| N773SA|   387|   SEA| MDW|    null|    1733|   0|     0|2014-01-30 00:00:00|
# |2014|    2|  8|      NA|       NA|      NA|       NA|     OO| N593ML|  6250|   PDX| LAX|    null|     834|   0|     0|2014-02-08 00:00:00|
# |2014|    2|  4|      NA|       NA|      NA|       NA|     AA| N3DRAA|   125|   SEA| ORD|    null|    1721|   0|     0|2014-02-04 00:00:00|
# |2014|   10| 14|      NA|       NA|      NA|       NA|     AS| N529AS|   413|   PDX| SEA|    null|     129|   0|     0|2014-10-14 00:00:00|
# |2014|    2| 17|      NA|       NA|      NA|       NA|     WN| N449WN|  1900|   SEA| MDW|    null|    1733|   0|     0|2014-02-17 00:00:00|
# |2014|    8| 12|      NA|       NA|      NA|       NA|     OO| N162PQ|  4489|   SEA| PDX|    null|     129|   0|     0|2014-08-12 00:00:00|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+-------------------+

# %%
flights = flights.withColumn('dep_time',
                            F.when(F.col('dep_time') == 'NA', 
                                   F.concat(F.col('hour').cast(StringType()), 
                                            F.lpad(F.col('minute').cast(StringType()), 2, '0')))
                            .otherwise(F.col('dep_time')))

# %%
flights.toPandas()
# Out:
#       year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0     2014     12    8      658        -7      935        -5      VX  N846VA
# 1     2014      1   22     1040         5     1505         5      AS  N559AS
# 2     2014      3    9     1443        -2     1652         2      VX  N847VA
# 3     2014      4    9     1705        45     1839        34      WN  N360SW
# 4     2014      3    9      754        -1     1015         1      AS  N612AS
# ...    ...    ...  ...      ...       ...      ...       ...     ...     ...
# 9995  2014      6   23     1806        -4     2104        -6      OO  N225AG
# 9996  2014      8   31     2336        11      452       -13      AA  N3LEAA
# 9997  2014      8    8      904        -1     1042        -5      AS  N523AS
# 9998  2014      8   29     1441        26     1820        10      WN  N8647A
# 9999  2014      7   13     1702        -3     1950       -10      DL  N583NW
#
#      flight origin dest  air_time  distance  hour  minute        dep_datetime
# 0      1780    SEA  LAX     132.0       954     6      58 2014-12-08 06:58:00
# 1       851    SEA  HNL     360.0      2677    10      40 2014-01-22 10:40:00
# 2       755    SEA  SFO     111.0       679    14      43 2014-03-09 14:43:00
# 3       344    PDX  SJC      83.0       569    17       5 2014-04-09 17:05:00
# 4       522    SEA  BUR     127.0       937     7      54 2014-03-09 07:54:00
# ...     ...    ...  ...       ...       ...   ...     ...                 ...
# 9995   3458    SEA  SLC      89.0       689    18       6 2014-06-23 18:06:00
# 9996   1230    SEA  DFW     178.0      1660    23      36 2014-08-31 23:36:00
# 9997    360    SEA  SMF      81.0       605     9       4 2014-08-08 09:04:00
# 9998   2857    SEA  ABQ     133.0      1180    14      41 2014-08-29 14:41:00
# 9999   2237    SEA  HNL     332.0      2677    17       2 2014-07-13 17:02:00
#
# [10000 rows x 17 columns]

# %% [markdown]
# ### Pergunta 5

# %%
flights.filter(F.col('dep_delay') == 'NA').toPandas()
# Out:
#     year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0   2014      3    4      000        NA       NA        NA      UA      NA
# 1   2014      2   12      000        NA       NA        NA      AS  N527AS
# 2   2014      7    1      000        NA       NA        NA      WN  N8323C
# 3   2014      4   30      000        NA       NA        NA      AS  N526AS
# 4   2014      1    3      000        NA       NA        NA      US      NA
# 5   2014      8    7      000        NA       NA        NA      AS  N579AS
# 6   2014      8   11      000        NA       NA        NA      OO  N689CA
# 7   2014      1    2      000        NA       NA        NA      UA      NA
# 8   2014      5   15      000        NA       NA        NA      OO  N917SW
# 9   2014      2    7      000        NA       NA        NA      OO  N594SW
# 10  2014      6    6      000        NA       NA        NA      WN  N645SW
# 11  2014      1    5      000        NA       NA        NA      UA      NA
# 12  2014      1    6      000        NA       NA        NA      UA      NA
# 13  2014      3   30      000        NA       NA        NA      US      NA
# 14  2014      2    9      000        NA       NA        NA      OO  N580SW
# 15  2014      2    9      000        NA       NA        NA      OO  N297SW
# 16  2014      1    1      000        NA       NA        NA      OO  N295SW
# 17  2014      2   17      000        NA       NA        NA      AA  N3LCAA
# 18  2014      1    5      000        NA       NA        NA      UA      NA
# 19  2014      5   26      000        NA       NA        NA      UA      NA
# 20  2014      6   20      000        NA       NA        NA      UA      NA
# 21  2014      8   10      000        NA       NA        NA      OO  N689CA
# 22  2014      2   16      000        NA       NA        NA      UA      NA
# 23  2014     11   13      000        NA       NA        NA      OO  N617QX
# 24  2014      4   25      000        NA       NA        NA      OO  N216AG
# 25  2014      1   28      000        NA       NA        NA      DL  N3744F
# 26  2014      1    6      000        NA       NA        NA      B6  N805JB
# 27  2014      1    4      000        NA       NA        NA      WN  N400WN
# 28  2014      9   24      000        NA       NA        NA      OO  N983CA
# 29  2014      7    3      000        NA       NA        NA      OO  N953SW
# 30  2014      2    9      000        NA       NA        NA      OO  N580SW
# 31  2014     12   16      000        NA       NA        NA      OO  N963SW
# 32  2014      9   26      000        NA       NA        NA      AS  N514AS
# 33  2014      2    4      000        NA       NA        NA      DL  N721TW
# 34  2014      1   18      000        NA       NA        NA      OO  N568SW
# 35  2014      1    5      000        NA       NA        NA      UA      NA
# 36  2014      8   16      000        NA       NA        NA      UA      NA
# 37  2014     10    2      000        NA       NA        NA      WN  N8647A
# 38  2014      1    5      000        NA       NA        NA      UA      NA
# 39  2014      2   16      000        NA       NA        NA      US      NA
# 40  2014      2   27      000        NA       NA        NA      OO  N946SW
# 41  2014      2    9      000        NA       NA        NA      AS  N627AS
# 42  2014      1   30      000        NA       NA        NA      WN  N773SA
# 43  2014      2    8      000        NA       NA        NA      OO  N593ML
# 44  2014      2    4      000        NA       NA        NA      AA  N3DRAA
# 45  2014     10   14      000        NA       NA        NA      AS  N529AS
# 46  2014      2   17      000        NA       NA        NA      WN  N449WN
# 47  2014      8   12      000        NA       NA        NA      OO  N162PQ
#
#    flight origin dest  air_time  distance  hour  minute dep_datetime
# 0     156    SEA  DEN       NaN      1024     0       0   2014-03-04
# 1       2    SEA  DCA       NaN      2329     0       0   2014-02-12
# 2    2485    SEA  MDW       NaN      1733     0       0   2014-07-01
# 3     566    PDX  LAX       NaN       834     0       0   2014-04-30
# 4     553    SEA  PHL       NaN      2378     0       0   2014-01-03
# 5     867    SEA  OGG       NaN      2640     0       0   2014-08-07
# 6    4528    PDX  SEA       NaN       129     0       0   2014-08-11
# 7     212    SEA  EWR       NaN      2402     0       0   2014-01-02
# 8    6250    PDX  LAX       NaN       834     0       0   2014-05-15
# 9    5553    PDX  SFO       NaN       550     0       0   2014-02-07
# 10    956    PDX  OAK       NaN       543     0       0   2014-06-06
# 11    758    PDX  IAH       NaN      1825     0       0   2014-01-05
# 12   1729    SEA  DEN       NaN      1024     0       0   2014-01-06
# 13    500    SEA  PHX       NaN      1107     0       0   2014-03-30
# 14   5438    PDX  EUG       NaN       106     0       0   2014-02-09
# 15   5342    SEA  PDX       NaN       129     0       0   2014-02-09
# 16   5403    PDX  EUG       NaN       106     0       0   2014-01-01
# 17   1236    SEA  ORD       NaN      1721     0       0   2014-02-17
# 18    995    PDX  SFO       NaN       550     0       0   2014-01-05
# 19    690    SEA  ORD       NaN      1721     0       0   2014-05-26
# 20   1142    SEA  IAH       NaN      1874     0       0   2014-06-20
# 21   4528    PDX  SEA       NaN       129     0       0   2014-08-10
# 22   1523    SEA  SFO       NaN       679     0       0   2014-02-16
# 23   4825    PDX  SEA       NaN       129     0       0   2014-11-13
# 24   3478    PDX  LGB       NaN       846     0       0   2014-04-25
# 25   2482    PDX  ATL       NaN      2172     0       0   2014-01-28
# 26    598    SEA  BOS       NaN      2496     0       0   2014-01-06
# 27   4174    SEA  DEN       NaN      1024     0       0   2014-01-04
# 28   5197    PDX  SFO       NaN       550     0       0   2014-09-24
# 29   5210    PDX  SFO       NaN       550     0       0   2014-07-03
# 30   5433    SEA  PDX       NaN       129     0       0   2014-02-09
# 31   5197    PDX  SFO       NaN       550     0       0   2014-12-16
# 32    686    PDX  ORD       NaN      1739     0       0   2014-09-26
# 33    182    SEA  JFK       NaN      2422     0       0   2014-02-04
# 34   5379    PDX  SEA       NaN       129     0       0   2014-01-18
# 35   1599    SEA  ORD       NaN      1721     0       0   2014-01-05
# 36   1752    SEA  SFO       NaN       679     0       0   2014-08-16
# 37    827    SEA  MDW       NaN      1733     0       0   2014-10-02
# 38    732    SEA  ORD       NaN      1721     0       0   2014-01-05
# 39    614    SEA  PHX       NaN      1107     0       0   2014-02-16
# 40   5196    PDX  SFO       NaN       550     0       0   2014-02-27
# 41    682    SEA  DEN       NaN      1024     0       0   2014-02-09
# 42    387    SEA  MDW       NaN      1733     0       0   2014-01-30
# 43   6250    PDX  LAX       NaN       834     0       0   2014-02-08
# 44    125    SEA  ORD       NaN      1721     0       0   2014-02-04
# 45    413    PDX  SEA       NaN       129     0       0   2014-10-14
# 46   1900    SEA  MDW       NaN      1733     0       0   2014-02-17
# 47   4489    SEA  PDX       NaN       129     0       0   2014-08-12

# %%
flights = flights.withColumn('dep_delay',
                            F.when(F.col('dep_delay') == 'NA', 0)
                            .otherwise(F.col('dep_delay')))

# %%
flights.toPandas()
# Out:
#       year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0     2014     12    8      658        -7      935        -5      VX  N846VA
# 1     2014      1   22     1040         5     1505         5      AS  N559AS
# 2     2014      3    9     1443        -2     1652         2      VX  N847VA
# 3     2014      4    9     1705        45     1839        34      WN  N360SW
# 4     2014      3    9      754        -1     1015         1      AS  N612AS
# ...    ...    ...  ...      ...       ...      ...       ...     ...     ...
# 9995  2014      6   23     1806        -4     2104        -6      OO  N225AG
# 9996  2014      8   31     2336        11      452       -13      AA  N3LEAA
# 9997  2014      8    8      904        -1     1042        -5      AS  N523AS
# 9998  2014      8   29     1441        26     1820        10      WN  N8647A
# 9999  2014      7   13     1702        -3     1950       -10      DL  N583NW
#
#      flight origin dest  air_time  distance  hour  minute        dep_datetime
# 0      1780    SEA  LAX     132.0       954     6      58 2014-12-08 06:58:00
# 1       851    SEA  HNL     360.0      2677    10      40 2014-01-22 10:40:00
# 2       755    SEA  SFO     111.0       679    14      43 2014-03-09 14:43:00
# 3       344    PDX  SJC      83.0       569    17       5 2014-04-09 17:05:00
# 4       522    SEA  BUR     127.0       937     7      54 2014-03-09 07:54:00
# ...     ...    ...  ...       ...       ...   ...     ...                 ...
# 9995   3458    SEA  SLC      89.0       689    18       6 2014-06-23 18:06:00
# 9996   1230    SEA  DFW     178.0      1660    23      36 2014-08-31 23:36:00
# 9997    360    SEA  SMF      81.0       605     9       4 2014-08-08 09:04:00
# 9998   2857    SEA  ABQ     133.0      1180    14      41 2014-08-29 14:41:00
# 9999   2237    SEA  HNL     332.0      2677    17       2 2014-07-13 17:02:00
#
# [10000 rows x 17 columns]

# %% [markdown]
# ### Pergunta 6

# %%
flights.filter(F.col('arr_delay') == 'NA').toPandas()
# Out:
# Empty DataFrame
# Columns: [year, month, day, dep_time, dep_delay, arr_time, arr_delay, carrier, tailnum, flight, origin, dest, air_time, distance, hour, minute, dep_datetime]
# Index: []

# %%
flights = flights.withColumn('arr_delay',
                            F.when(F.col('arr_delay') == 'NA', 0)
                            .otherwise(F.col('arr_delay')))

# %%
flights.toPandas()
# Out:
#       year  month  day dep_time dep_delay arr_time arr_delay carrier tailnum  \
# 0     2014     12    8      658        -7      935        -5      VX  N846VA
# 1     2014      1   22     1040         5     1505         5      AS  N559AS
# 2     2014      3    9     1443        -2     1652         2      VX  N847VA
# 3     2014      4    9     1705        45     1839        34      WN  N360SW
# 4     2014      3    9      754        -1     1015         1      AS  N612AS
# ...    ...    ...  ...      ...       ...      ...       ...     ...     ...
# 9995  2014      6   23     1806        -4     2104        -6      OO  N225AG
# 9996  2014      8   31     2336        11      452       -13      AA  N3LEAA
# 9997  2014      8    8      904        -1     1042        -5      AS  N523AS
# 9998  2014      8   29     1441        26     1820        10      WN  N8647A
# 9999  2014      7   13     1702        -3     1950       -10      DL  N583NW
#
#      flight origin dest  air_time  distance  hour  minute        dep_datetime
# 0      1780    SEA  LAX     132.0       954     6      58 2014-12-08 06:58:00
# 1       851    SEA  HNL     360.0      2677    10      40 2014-01-22 10:40:00
# 2       755    SEA  SFO     111.0       679    14      43 2014-03-09 14:43:00
# 3       344    PDX  SJC      83.0       569    17       5 2014-04-09 17:05:00
# 4       522    SEA  BUR     127.0       937     7      54 2014-03-09 07:54:00
# ...     ...    ...  ...       ...       ...   ...     ...                 ...
# 9995   3458    SEA  SLC      89.0       689    18       6 2014-06-23 18:06:00
# 9996   1230    SEA  DFW     178.0      1660    23      36 2014-08-31 23:36:00
# 9997    360    SEA  SMF      81.0       605     9       4 2014-08-08 09:04:00
# 9998   2857    SEA  ABQ     133.0      1180    14      41 2014-08-29 14:41:00
# 9999   2237    SEA  HNL     332.0      2677    17       2 2014-07-13 17:02:00
#
# [10000 rows x 17 columns]

# %% [markdown]
# ### Pergunta 7

# %%
flights = flights.drop('year', 'month', 'day', 'hour', 'minute')

# %%
flights.show()
# Out:
# +--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+-------------------+
# |dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|       dep_datetime|
# +--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+-------------------+
# |     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA| LAX|     132|     954|2014-12-08 06:58:00|
# |    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA| HNL|     360|    2677|2014-01-22 10:40:00|
# |    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA| SFO|     111|     679|2014-03-09 14:43:00|
# |    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX| SJC|      83|     569|2014-04-09 17:05:00|
# |     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA| BUR|     127|     937|2014-03-09 07:54:00|
# |    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX| DEN|     121|     991|2014-01-15 10:37:00|
# |     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX| OAK|      90|     543|2014-07-02 08:47:00|
# |    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA| SFO|      98|     679|2014-05-12 16:55:00|
# |    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA| SAN|     135|    1050|2014-04-19 12:36:00|
# |    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA| ORD|     198|    1721|2014-11-19 18:12:00|
# |    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA| LAX|     130|     954|2014-11-08 16:53:00|
# |    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA| PHX|     154|    1107|2014-08-03 11:20:00|
# |     811|       21|    1038|       29|     AS| N433AS|   608|   SEA| LAS|     127|     867|2014-10-30 08:11:00|
# |    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA| ANC|     183|    1448|2014-11-12 23:46:00|
# |    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA| SFO|     129|     679|2014-10-31 13:14:00|
# |    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX| SFO|      90|     550|2014-01-29 20:09:00|
# |    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA| SMF|      76|     605|2014-12-17 20:15:00|
# |    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA| MDW|     216|    1733|2014-08-11 10:17:00|
# |    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA| BOS|     290|    2496|2014-01-13 21:56:00|
# |    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX| BUR|     111|     817|2014-06-05 17:33:00|
# +--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+-------------------+
# only showing top 20 rows

# %% [markdown]
# ### Pergunta 8

# %%
flights = flights.withColumn('air_time_projected',
                            F.round((F.col('distance') * 0.1 + 20), 0).cast('int'))

# %%
flights.toPandas()
# Out:
#      dep_time dep_delay arr_time arr_delay carrier tailnum flight origin dest  \
# 0         658        -7      935        -5      VX  N846VA   1780    SEA  LAX
# 1        1040         5     1505         5      AS  N559AS    851    SEA  HNL
# 2        1443        -2     1652         2      VX  N847VA    755    SEA  SFO
# 3        1705        45     1839        34      WN  N360SW    344    PDX  SJC
# 4         754        -1     1015         1      AS  N612AS    522    SEA  BUR
# ...       ...       ...      ...       ...     ...     ...    ...    ...  ...
# 9995     1806        -4     2104        -6      OO  N225AG   3458    SEA  SLC
# 9996     2336        11      452       -13      AA  N3LEAA   1230    SEA  DFW
# 9997      904        -1     1042        -5      AS  N523AS    360    SEA  SMF
# 9998     1441        26     1820        10      WN  N8647A   2857    SEA  ABQ
# 9999     1702        -3     1950       -10      DL  N583NW   2237    SEA  HNL
#
#       air_time  distance        dep_datetime  air_time_projected
# 0        132.0       954 2014-12-08 06:58:00                 115
# 1        360.0      2677 2014-01-22 10:40:00                 288
# 2        111.0       679 2014-03-09 14:43:00                  88
# 3         83.0       569 2014-04-09 17:05:00                  77
# 4        127.0       937 2014-03-09 07:54:00                 114
# ...        ...       ...                 ...                 ...
# 9995      89.0       689 2014-06-23 18:06:00                  89
# 9996     178.0      1660 2014-08-31 23:36:00                 186
# 9997      81.0       605 2014-08-08 09:04:00                  81
# 9998     133.0      1180 2014-08-29 14:41:00                 138
# 9999     332.0      2677 2014-07-13 17:02:00                 288
#
# [10000 rows x 13 columns]

# %% [markdown]
# ### Pergunta 9

# %%
flights_mean = flights.groupBy(F.col('dest'), F.col('origin'))\
    .agg(F.round(F.avg('air_time'), 0).cast('int').alias('air_time_expected'))

# %%
flights_mean.show()
# Out:
# +----+------+-----------------+
# |dest|origin|air_time_expected|
# +----+------+-----------------+
# | ORD|   PDX|              206|
# | HOU|   PDX|              226|
# | IAD|   SEA|              264|
# | CLE|   SEA|              234|
# | BWI|   SEA|              270|
# | DEN|   SEA|              127|
# | RNO|   SEA|               74|
# | PSP|   SEA|              129|
# | STL|   PDX|              204|
# | SJC|   PDX|               86|
# | DFW|   SEA|              196|
# | COS|   SEA|              133|
# | SNA|   PDX|              121|
# | PDX|   SEA|               33|
# | LMT|   PDX|               54|
# | MDW|   PDX|              214|
# | MCI|   PDX|              174|
# | EUG|   PDX|               27|
# | DFW|   PDX|              192|
# | SMF|   PDX|               68|
# +----+------+-----------------+
# only showing top 20 rows

# %%
flights = flights.alias('f1').join(flights_mean.alias('f2'),\
                         (F.col('f1.origin') == F.col('f2.origin')) &
                         (F.col('f1.dest') == F.col('f2.dest')), 'inner')\
                        .select('f1.dep_time', 
                                'f1.dep_delay', 
                                'f1.arr_time', 
                                'f1.arr_delay', 
                                'f1.carrier', 
                                'f1.tailnum',
                                'f1.flight', 
                                'f1.origin', 
                                'f1.dest', 
                                'f1.air_time', 
                                'f1.distance', 
                                'f1.dep_datetime',
                                'f1.air_time_projected', 
                                'f2.air_time_expected')

# %%
flights.toPandas()
# Out:
#      dep_time dep_delay arr_time arr_delay carrier tailnum flight origin dest  \
# 0         658        -7      935        -5      VX  N846VA   1780    SEA  LAX
# 1        1040         5     1505         5      AS  N559AS    851    SEA  HNL
# 2        1443        -2     1652         2      VX  N847VA    755    SEA  SFO
# 3        1705        45     1839        34      WN  N360SW    344    PDX  SJC
# 4         754        -1     1015         1      AS  N612AS    522    SEA  BUR
# ...       ...       ...      ...       ...     ...     ...    ...    ...  ...
# 9995     1806        -4     2104        -6      OO  N225AG   3458    SEA  SLC
# 9996     2336        11      452       -13      AA  N3LEAA   1230    SEA  DFW
# 9997      904        -1     1042        -5      AS  N523AS    360    SEA  SMF
# 9998     1441        26     1820        10      WN  N8647A   2857    SEA  ABQ
# 9999     1702        -3     1950       -10      DL  N583NW   2237    SEA  HNL
#
#       air_time  distance        dep_datetime  air_time_projected  \
# 0        132.0       954 2014-12-08 06:58:00                 115
# 1        360.0      2677 2014-01-22 10:40:00                 288
# 2        111.0       679 2014-03-09 14:43:00                  88
# 3         83.0       569 2014-04-09 17:05:00                  77
# 4        127.0       937 2014-03-09 07:54:00                 114
# ...        ...       ...                 ...                 ...
# 9995      89.0       689 2014-06-23 18:06:00                  89
# 9996     178.0      1660 2014-08-31 23:36:00                 186
# 9997      81.0       605 2014-08-08 09:04:00                  81
# 9998     133.0      1180 2014-08-29 14:41:00                 138
# 9999     332.0      2677 2014-07-13 17:02:00                 288
#
#       air_time_expected
# 0                   127
# 1                   344
# 2                   101
# 3                    86
# 4                   122
# ...                 ...
# 9995                 89
# 9996                196
# 9997                 83
# 9998                143
# 9999                344
#
# [10000 rows x 14 columns]

# %% [markdown]
# ### Pergunta 10

# %%
flights.toPandas()
# Out:
#      dep_time dep_delay arr_time arr_delay carrier tailnum flight origin dest  \
# 0         658        -7      935        -5      VX  N846VA   1780    SEA  LAX
# 1        1040         5     1505         5      AS  N559AS    851    SEA  HNL
# 2        1443        -2     1652         2      VX  N847VA    755    SEA  SFO
# 3        1705        45     1839        34      WN  N360SW    344    PDX  SJC
# 4         754        -1     1015         1      AS  N612AS    522    SEA  BUR
# ...       ...       ...      ...       ...     ...     ...    ...    ...  ...
# 9995     1806        -4     2104        -6      OO  N225AG   3458    SEA  SLC
# 9996     2336        11      452       -13      AA  N3LEAA   1230    SEA  DFW
# 9997      904        -1     1042        -5      AS  N523AS    360    SEA  SMF
# 9998     1441        26     1820        10      WN  N8647A   2857    SEA  ABQ
# 9999     1702        -3     1950       -10      DL  N583NW   2237    SEA  HNL
#
#       air_time  distance        dep_datetime  air_time_projected  \
# 0        132.0       954 2014-12-08 06:58:00                 115
# 1        360.0      2677 2014-01-22 10:40:00                 288
# 2        111.0       679 2014-03-09 14:43:00                  88
# 3         83.0       569 2014-04-09 17:05:00                  77
# 4        127.0       937 2014-03-09 07:54:00                 114
# ...        ...       ...                 ...                 ...
# 9995      89.0       689 2014-06-23 18:06:00                  89
# 9996     178.0      1660 2014-08-31 23:36:00                 186
# 9997      81.0       605 2014-08-08 09:04:00                  81
# 9998     133.0      1180 2014-08-29 14:41:00                 138
# 9999     332.0      2677 2014-07-13 17:02:00                 288
#
#       air_time_expected
# 0                   127
# 1                   344
# 2                   101
# 3                    86
# 4                   122
# ...                 ...
# 9995                 89
# 9996                196
# 9997                 83
# 9998                143
# 9999                344
#
# [10000 rows x 14 columns]

# %%
flights = flights.withColumn('air_time',
                  F.greatest(F.col('air_time_projected'), F.col('air_time_expected')))

# %%
flights.toPandas()
# Out:
#      dep_time dep_delay arr_time arr_delay carrier tailnum flight origin dest  \
# 0         658        -7      935        -5      VX  N846VA   1780    SEA  LAX
# 1        1040         5     1505         5      AS  N559AS    851    SEA  HNL
# 2        1443        -2     1652         2      VX  N847VA    755    SEA  SFO
# 3        1705        45     1839        34      WN  N360SW    344    PDX  SJC
# 4         754        -1     1015         1      AS  N612AS    522    SEA  BUR
# ...       ...       ...      ...       ...     ...     ...    ...    ...  ...
# 9995     1806        -4     2104        -6      OO  N225AG   3458    SEA  SLC
# 9996     2336        11      452       -13      AA  N3LEAA   1230    SEA  DFW
# 9997      904        -1     1042        -5      AS  N523AS    360    SEA  SMF
# 9998     1441        26     1820        10      WN  N8647A   2857    SEA  ABQ
# 9999     1702        -3     1950       -10      DL  N583NW   2237    SEA  HNL
#
#       air_time  distance        dep_datetime  air_time_projected  \
# 0          127       954 2014-12-08 06:58:00                 115
# 1          344      2677 2014-01-22 10:40:00                 288
# 2          101       679 2014-03-09 14:43:00                  88
# 3           86       569 2014-04-09 17:05:00                  77
# 4          122       937 2014-03-09 07:54:00                 114
# ...        ...       ...                 ...                 ...
# 9995        89       689 2014-06-23 18:06:00                  89
# 9996       196      1660 2014-08-31 23:36:00                 186
# 9997        83       605 2014-08-08 09:04:00                  81
# 9998       143      1180 2014-08-29 14:41:00                 138
# 9999       344      2677 2014-07-13 17:02:00                 288
#
#       air_time_expected
# 0                   127
# 1                   344
# 2                   101
# 3                    86
# 4                   122
# ...                 ...
# 9995                 89
# 9996                196
# 9997                 83
# 9998                143
# 9999                344
#
# [10000 rows x 14 columns]

# %% [markdown]
# ### Pergunta 11

# %%
flights = flights.withColumn('dep_time_m',
                  F.when(F.length(F.col('dep_time')) == 3, 
                         (F.substring(F.col('dep_time'), 1, 1). cast('int') * 60) + 
                         F.substring(F.col('dep_time'), 2, 2).cast('int'))
                  .otherwise(
                      (F.substring(F.col('dep_time'), 1, 2).cast('int') * 60) + 
                      F.substring(F.col('dep_time'), 3, 2).cast('int')))

# %%
flights = flights.withColumn('arr_time_',
                  F.concat(F.floor((F.col('dep_time_m') + F.col('air_time')) / 60).cast(StringType()), 
                           F.lpad((F.col('dep_time_m') + F.col('air_time')) % 60, 2, '0').cast(StringType())))

# %%
flights = flights.withColumn('arr_time_',
                  F.when((F.length(F.col('arr_time_')) == 4) & 
                         (F.substring(F.col('arr_time_'), 1, 2).cast('int') > 23), 
                                F.concat((F.substring(F.col('arr_time_'), 1, 2).cast('int') - 24).cast(StringType()),
                                F.substring(F.col('arr_time_'), 3, 2)))
                  .otherwise(F.col('arr_time_'))).drop('dep_time_m')

# %%
flights.toPandas()
# Out:
#      dep_time dep_delay arr_time arr_delay carrier tailnum flight origin dest  \
# 0         658        -7      935        -5      VX  N846VA   1780    SEA  LAX
# 1        1040         5     1505         5      AS  N559AS    851    SEA  HNL
# 2        1443        -2     1652         2      VX  N847VA    755    SEA  SFO
# 3        1705        45     1839        34      WN  N360SW    344    PDX  SJC
# 4         754        -1     1015         1      AS  N612AS    522    SEA  BUR
# ...       ...       ...      ...       ...     ...     ...    ...    ...  ...
# 9995     1806        -4     2104        -6      OO  N225AG   3458    SEA  SLC
# 9996     2336        11      452       -13      AA  N3LEAA   1230    SEA  DFW
# 9997      904        -1     1042        -5      AS  N523AS    360    SEA  SMF
# 9998     1441        26     1820        10      WN  N8647A   2857    SEA  ABQ
# 9999     1702        -3     1950       -10      DL  N583NW   2237    SEA  HNL
#
#       air_time  distance        dep_datetime  air_time_projected  \
# 0          127       954 2014-12-08 06:58:00                 115
# 1          344      2677 2014-01-22 10:40:00                 288
# 2          101       679 2014-03-09 14:43:00                  88
# 3           86       569 2014-04-09 17:05:00                  77
# 4          122       937 2014-03-09 07:54:00                 114
# ...        ...       ...                 ...                 ...
# 9995        89       689 2014-06-23 18:06:00                  89
# 9996       196      1660 2014-08-31 23:36:00                 186
# 9997        83       605 2014-08-08 09:04:00                  81
# 9998       143      1180 2014-08-29 14:41:00                 138
# 9999       344      2677 2014-07-13 17:02:00                 288
#
#       air_time_expected arr_time_
# 0                   127       905
# 1                   344      1624
# 2                   101      1624
# 3                    86      1831
# 4                   122       956
# ...                 ...       ...
# 9995                 89      1935
# 9996                196       252
# 9997                 83      1027
# 9998                143      1704
# 9999                344      2246
#
# [10000 rows x 15 columns]

# %% [markdown]
# ### Pergunta 12

# %%
flights = flights.withColumn('haul_duration',
                            F.when(F.col('air_time').between(20, 180), 'SHORT-HAUL')
                            .when(F.col('air_time').between(180, 360), 'MEDIUM-HAUL')
                            .when(F.col('air_time') > 360, 'LONG-HAUL'))

# %%
flights.toPandas()
# Out:
#      dep_time dep_delay arr_time arr_delay carrier tailnum flight origin dest  \
# 0         658        -7      935        -5      VX  N846VA   1780    SEA  LAX
# 1        1040         5     1505         5      AS  N559AS    851    SEA  HNL
# 2        1443        -2     1652         2      VX  N847VA    755    SEA  SFO
# 3        1705        45     1839        34      WN  N360SW    344    PDX  SJC
# 4         754        -1     1015         1      AS  N612AS    522    SEA  BUR
# ...       ...       ...      ...       ...     ...     ...    ...    ...  ...
# 9995     1806        -4     2104        -6      OO  N225AG   3458    SEA  SLC
# 9996     2336        11      452       -13      AA  N3LEAA   1230    SEA  DFW
# 9997      904        -1     1042        -5      AS  N523AS    360    SEA  SMF
# 9998     1441        26     1820        10      WN  N8647A   2857    SEA  ABQ
# 9999     1702        -3     1950       -10      DL  N583NW   2237    SEA  HNL
#
#       air_time  distance        dep_datetime  air_time_projected  \
# 0          127       954 2014-12-08 06:58:00                 115
# 1          344      2677 2014-01-22 10:40:00                 288
# 2          101       679 2014-03-09 14:43:00                  88
# 3           86       569 2014-04-09 17:05:00                  77
# 4          122       937 2014-03-09 07:54:00                 114
# ...        ...       ...                 ...                 ...
# 9995        89       689 2014-06-23 18:06:00                  89
# 9996       196      1660 2014-08-31 23:36:00                 186
# 9997        83       605 2014-08-08 09:04:00                  81
# 9998       143      1180 2014-08-29 14:41:00                 138
# 9999       344      2677 2014-07-13 17:02:00                 288
#
#       air_time_expected arr_time_ haul_duration
# 0                   127       905    SHORT-HAUL
# 1                   344      1624   MEDIUM-HAUL
# 2                   101      1624    SHORT-HAUL
# 3                    86      1831    SHORT-HAUL
# 4                   122       956    SHORT-HAUL
# ...                 ...       ...           ...
# 9995                 89      1935    SHORT-HAUL
# 9996                196       252   MEDIUM-HAUL
# 9997                 83      1027    SHORT-HAUL
# 9998                143      1704    SHORT-HAUL
# 9999                344      2246   MEDIUM-HAUL
#
# [10000 rows x 16 columns]

# %% [markdown]
# ### Pergunta 13

# %%
flights.orderBy('dep_datetime').toPandas()
# Out:
#      dep_time dep_delay arr_time arr_delay carrier tailnum flight origin dest  \
# 0         000         0       NA         0      OO  N295SW   5403    PDX  EUG
# 1         550         0      837       -12      DL  N660DL   1634    SEA  SLC
# 2         600       -10      842        -8      AS  N786AS    426    SEA  LAX
# 3         617         2      850       -12      AS  N579AS    494    SEA  SAN
# 4         619        -6      822        -7      VX  N841VA    751    SEA  SFO
# ...       ...       ...      ...       ...     ...     ...    ...    ...  ...
# 9995     1755         0     2149        10      US  N536UW    576    SEA  PHX
# 9996     1755         0     1957        -7      AS  N403AS    302    SEA  SFO
# 9997     2054        -1     2326         7      AS  N519AS    534    SEA  ONT
# 9998     2120        -5        6        -9      AS  N768AS    121    SEA  ANC
# 9999     2257        -3        6         9      AS  N532AS    698    SEA  GEG
#
#       air_time  distance        dep_datetime  air_time_projected  \
# 0           31       106 2014-01-01 00:00:00                  31
# 1           89       689 2014-01-01 05:50:00                  89
# 2          127       954 2014-01-01 06:00:00                 115
# 3          138      1050 2014-01-01 06:17:00                 125
# 4          101       679 2014-01-01 06:19:00                  88
# ...        ...       ...                 ...                 ...
# 9995       142      1107 2014-12-31 17:55:00                 131
# 9996       101       679 2014-12-31 17:55:00                  88
# 9997       125       956 2014-12-31 20:54:00                 116
# 9998       191      1448 2014-12-31 21:20:00                 165
# 9999        42       224 2014-12-31 22:57:00                  42
#
#       air_time_expected arr_time_ haul_duration
# 0                    27       031    SHORT-HAUL
# 1                    89       719    SHORT-HAUL
# 2                   127       807    SHORT-HAUL
# 3                   138       835    SHORT-HAUL
# 4                   101       800    SHORT-HAUL
# ...                 ...       ...           ...
# 9995                142      2017    SHORT-HAUL
# 9996                101      1936    SHORT-HAUL
# 9997                125      2259    SHORT-HAUL
# 9998                191       031   MEDIUM-HAUL
# 9999                 38      2339    SHORT-HAUL
#
# [10000 rows x 16 columns]

# %%
flights = flights.withColumn('dep_season',
                  F.when(F.col('dep_datetime').between('2013-12-21 21:48', '2014-03-20 15:33') | 
                         F.col('dep_datetime').between('2014-12-21 21:48', '2015-03-20 15:33'), 'WINTER')
                  .when(F.col('dep_datetime').between('2014-03-20 15:33', '2014-06-21 10:14'), 'SPRING')
                  .when(F.col('dep_datetime').between('2014-06-21 10:14', '2014-09-23 02:04'), 'SUMMER')
                  .when(F.col('dep_datetime').between('2014-09-23 02:04', '2014-12-21 21:48'), 'FALL'))

# %%
flights.toPandas()
# Out:
#      dep_time dep_delay arr_time arr_delay carrier tailnum flight origin dest  \
# 0         658        -7      935        -5      VX  N846VA   1780    SEA  LAX
# 1        1040         5     1505         5      AS  N559AS    851    SEA  HNL
# 2        1443        -2     1652         2      VX  N847VA    755    SEA  SFO
# 3        1705        45     1839        34      WN  N360SW    344    PDX  SJC
# 4         754        -1     1015         1      AS  N612AS    522    SEA  BUR
# ...       ...       ...      ...       ...     ...     ...    ...    ...  ...
# 9995     1806        -4     2104        -6      OO  N225AG   3458    SEA  SLC
# 9996     2336        11      452       -13      AA  N3LEAA   1230    SEA  DFW
# 9997      904        -1     1042        -5      AS  N523AS    360    SEA  SMF
# 9998     1441        26     1820        10      WN  N8647A   2857    SEA  ABQ
# 9999     1702        -3     1950       -10      DL  N583NW   2237    SEA  HNL
#
#       air_time  distance        dep_datetime  air_time_projected  \
# 0          127       954 2014-12-08 06:58:00                 115
# 1          344      2677 2014-01-22 10:40:00                 288
# 2          101       679 2014-03-09 14:43:00                  88
# 3           86       569 2014-04-09 17:05:00                  77
# 4          122       937 2014-03-09 07:54:00                 114
# ...        ...       ...                 ...                 ...
# 9995        89       689 2014-06-23 18:06:00                  89
# 9996       196      1660 2014-08-31 23:36:00                 186
# 9997        83       605 2014-08-08 09:04:00                  81
# 9998       143      1180 2014-08-29 14:41:00                 138
# 9999       344      2677 2014-07-13 17:02:00                 288
#
#       air_time_expected arr_time_ haul_duration dep_season
# 0                   127       905    SHORT-HAUL       FALL
# 1                   344      1624   MEDIUM-HAUL     WINTER
# 2                   101      1624    SHORT-HAUL     WINTER
# 3                    86      1831    SHORT-HAUL     SPRING
# 4                   122       956    SHORT-HAUL     WINTER
# ...                 ...       ...           ...        ...
# 9995                 89      1935    SHORT-HAUL     SUMMER
# 9996                196       252   MEDIUM-HAUL     SUMMER
# 9997                 83      1027    SHORT-HAUL     SUMMER
# 9998                143      1704    SHORT-HAUL     SUMMER
# 9999                344      2246   MEDIUM-HAUL     SUMMER
#
# [10000 rows x 17 columns]

# %% [markdown]
# ### Pergunta 14

# %%
flights = flights.withColumn('dep_delay_category',
                  F.when(F.col('dep_delay') < 0, 'ANTECIPATED')
                  .when(F.col('dep_delay') == 0, 'INTIME')
                  .when((F.col('dep_delay') > 0) & 
                        (F.col('dep_delay') < 60), 'MINOR')
                  .when(F.col('dep_delay') >= 60, 'MAJOR'))

# %%
flights.toPandas()
# Out:
#      dep_time dep_delay arr_time arr_delay carrier tailnum flight origin dest  \
# 0         658        -7      935        -5      VX  N846VA   1780    SEA  LAX
# 1        1040         5     1505         5      AS  N559AS    851    SEA  HNL
# 2        1443        -2     1652         2      VX  N847VA    755    SEA  SFO
# 3        1705        45     1839        34      WN  N360SW    344    PDX  SJC
# 4         754        -1     1015         1      AS  N612AS    522    SEA  BUR
# ...       ...       ...      ...       ...     ...     ...    ...    ...  ...
# 9995     1806        -4     2104        -6      OO  N225AG   3458    SEA  SLC
# 9996     2336        11      452       -13      AA  N3LEAA   1230    SEA  DFW
# 9997      904        -1     1042        -5      AS  N523AS    360    SEA  SMF
# 9998     1441        26     1820        10      WN  N8647A   2857    SEA  ABQ
# 9999     1702        -3     1950       -10      DL  N583NW   2237    SEA  HNL
#
#       air_time  distance        dep_datetime  air_time_projected  \
# 0          127       954 2014-12-08 06:58:00                 115
# 1          344      2677 2014-01-22 10:40:00                 288
# 2          101       679 2014-03-09 14:43:00                  88
# 3           86       569 2014-04-09 17:05:00                  77
# 4          122       937 2014-03-09 07:54:00                 114
# ...        ...       ...                 ...                 ...
# 9995        89       689 2014-06-23 18:06:00                  89
# 9996       196      1660 2014-08-31 23:36:00                 186
# 9997        83       605 2014-08-08 09:04:00                  81
# 9998       143      1180 2014-08-29 14:41:00                 138
# 9999       344      2677 2014-07-13 17:02:00                 288
#
#       air_time_expected arr_time_ haul_duration dep_season dep_delay_category
# 0                   127       905    SHORT-HAUL       FALL        ANTECIPATED
# 1                   344      1624   MEDIUM-HAUL     WINTER              MINOR
# 2                   101      1624    SHORT-HAUL     WINTER        ANTECIPATED
# 3                    86      1831    SHORT-HAUL     SPRING              MINOR
# 4                   122       956    SHORT-HAUL     WINTER        ANTECIPATED
# ...                 ...       ...           ...        ...                ...
# 9995                 89      1935    SHORT-HAUL     SUMMER        ANTECIPATED
# 9996                196       252   MEDIUM-HAUL     SUMMER              MINOR
# 9997                 83      1027    SHORT-HAUL     SUMMER        ANTECIPATED
# 9998                143      1704    SHORT-HAUL     SUMMER              MINOR
# 9999                344      2246   MEDIUM-HAUL     SUMMER        ANTECIPATED
#
# [10000 rows x 18 columns]

# %%
flights.write.parquet(
    mode = 'overwrite',
    path = 'C:/Practice_Pyspark/flights_proc/parquet')
